# %%
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
import csv

# %%
fields = ['Spin test #', 'q (spin overlap)']
rows = [[0, 0.52]]

# %%
with open('spin.csv', 'w') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(fields)
    csvwriter.writerows(rows)

# %%
spin_num = 100 # number of spin-sites
s = np.random.normal(0, 1, spin_num)

# %%
spin_dict_1 = {} # list of spins
spin_dict_2 = {}
for i in range(0, 100):
    random.seed()
    spin_dict_1[i] = random.choice([-1,1])

for key in spin_dict_1:
    spin_dict_2[key] = spin_dict_1[key]

# %%
def hamiltonian(spin, dict, flip = False): #compute energy given a spin site number
    sum = 0
    spin_value = dict[spin]
    # print(spin_value)
    if flip == True:
        spin_value = -spin_value
        # print(spin_value)
    if spin == 0:
        sum -= s[spin_num-1]*dict[spin_num-1]*spin_value
        sum -= s[spin]*spin_value*dict[spin+1]
    elif spin == spin_num - 1:
        sum -= s[spin-1]*dict[spin-1]*spin_value
        sum -= s[spin]*spin_value*dict[0]
    else:
        sum -= s[spin-1]*dict[spin-1]*spin_value
        sum -= s[spin]*spin_value*dict[spin+1]
    return sum

# %%
def flip_check(spin, dict):
    energy_unflipped = hamiltonian(spin, dict)
    energy_flipped = hamiltonian(spin, dict, flip = True)

    print(f"Spin site {spin}:")
    print(f"    Energy before flip is {energy_unflipped}")
    print(f"    Energy after flip is {energy_flipped}")

    if energy_flipped < energy_unflipped:
        dict[spin] = dict[spin] * (-1)
        print(f"    Spin site {spin} has been flipped.")
        return True
    else:
        print(f"    Spin site {spin} has not been flipped.")
        return False

# %%
def glauber(t, dict):
    t += 1/spin_num
    random.seed()
    spin = random.randint(0, spin_num-1)
    flip_check(spin, dict)
    return t

# %%
def monte_carlo(t, dict, active_dict):
    random.seed()
    spin = random.choice(list(active_dict.keys()))
    t += 1/len(active_dict)
    if not flip_check(spin, dict):
        active_dict.pop(spin)
        print(f"Spin site {spin} has been removed from active list")
    else: # spin has been flipped, neighbor sites are now active
        active_dict[spin] = active_dict[spin] * (-1)
        if spin == 0:
            if spin_num - 1 not in active_dict.keys():
                active_dict[spin_num-1] = dict[spin_num-1]
            if spin+1 not in active_dict.keys():
                active_dict[spin+1] = dict[spin+1]
        elif spin == spin_num-1:
            if spin - 1 not in active_dict.keys():
                active_dict[spin-1] = dict[spin-1]
            if 0 not in active_dict.keys():
                active_dict[0] = dict[0]
        else:
            if spin - 1 not in active_dict.keys():
                active_dict[spin-1] = dict[spin-1]
            if spin + 1 not in active_dict.keys():
                active_dict[spin+1] = dict[spin+1]
    return t

# %%
switch_time = 1

# %%
t = 0
while t < switch_time: # t measured in sweeps - one sweep = N spin-flip attempts
    t = glauber(t, spin_dict_1)
# print(t)
# Out:
# Spin site 68:
#     Energy before flip is 0.8837748834248461
#     Energy after flip is -0.8837748834248461
#     Spin site 68 has been flipped.
# Spin site 75:
#     Energy before flip is -1.2734469397123966
#     Energy after flip is 1.2734469397123966
#     Spin site 75 has not been flipped.
# Spin site 99:
#     Energy before flip is -0.8676913089738585
#     Energy after flip is 0.8676913089738585
#     Spin site 99 has not been flipped.
# Spin site 4:
#     Energy before flip is -0.37384193760642126
#     Energy after flip is 0.37384193760642126
#     Spin site 4 has not been flipped.
# Spin site 29:
#     Energy before flip is 0.5699917588146113
#     Energy after flip is -0.5699917588146113
#     Spin site 29 has been flipped.
# Spin site 34:
#     Energy before flip is -1.591325085946909
#     Energy after flip is 1.591325085946909
#     Spin site 34 has not been flipped.
# Spin site 39:
#     Energy before flip is -2.575612224233624
#     Energy after flip is 2.575612224233624
#     Spin site 39 has not been flipped.
# Spin site 54:
#     Energy before flip is -1.0788654283754342
#     Energy after flip is 1.0788654283754342
#     Spin site 54 has not been flipped.
# Spin site 21:
#     Energy before flip is 0.24602211523024617
#     Energy after flip is -0.24602211523024617
#     Spin site 21 has been flipped.
# Spin site 1:
#     Energy before flip is 0.5546805015207358
#     Energy after flip is -0.5546805015207358
#     Spin site 1 has been flipped.
# Spin site 40:
#     Energy before flip is -1.6898368009289364
#     Energy after flip is 1.6898368009289364
#     Spin site 40 has not been flipped.
# Spin site 47:
#     Energy before flip is -1.6094345788373585
#     Energy after flip is 1.6094345788373585
#     Spin site 47 has not been flipped.
# Spin site 32:
#     Energy before flip is 1.2515634205818116
#     Energy after flip is -1.2515634205818116
#     Spin site 32 has been flipped.
# Spin site 14:
#     Energy before flip is -1.2872437015347526
#     Energy after flip is 1.2872437015347526
#     Spin site 14 has not been flipped.
# Spin site 84:
#     Energy before flip is -0.6271592093859497
#     Energy after flip is 0.6271592093859497
#     Spin site 84 has not been flipped.
# Spin site 70:
#     Energy before flip is 0.3535871807904514
#     Energy after flip is -0.3535871807904514
#     Spin site 70 has been flipped.
# Spin site 14:
#     Energy before flip is -1.2872437015347526
#     Energy after flip is 1.2872437015347526
#     Spin site 14 has not been flipped.
# Spin site 52:
#     Energy before flip is -1.5085391844203349
#     Energy after flip is 1.5085391844203349
#     Spin site 52 has not been flipped.
# Spin site 64:
#     Energy before flip is -1.3597712976176775
#     Energy after flip is 1.3597712976176775
#     Spin site 64 has not been flipped.
# Spin site 78:
#     Energy before flip is 0.3754679709932716
#     Energy after flip is -0.3754679709932716
#     Spin site 78 has been flipped.
# Spin site 80:
#     Energy before flip is 1.240924769674217
#     Energy after flip is -1.240924769674217
#     Spin site 80 has been flipped.
# Spin site 14:
#     Energy before flip is -1.2872437015347526
#     Energy after flip is 1.2872437015347526
#     Spin site 14 has not been flipped.
# Spin site 87:
#     Energy before flip is -2.0981736432658433
#     Energy after flip is 2.0981736432658433
#     Spin site 87 has not been flipped.
# Spin site 19:
#     Energy before flip is 2.2816817154026467
#     Energy after flip is -2.2816817154026467
#     Spin site 19 has been flipped.
# Spin site 16:
#     Energy before flip is 0.4702827525195432
#     Energy after flip is -0.4702827525195432
#     Spin site 16 has been flipped.
# Spin site 12:
#     Energy before flip is 0.8877316829710786
#     Energy after flip is -0.8877316829710786
#     Spin site 12 has been flipped.
# Spin site 19:
#     Energy before flip is -2.2816817154026467
#     Energy after flip is 2.2816817154026467
#     Spin site 19 has not been flipped.
# Spin site 25:
#     Energy before flip is 0.6288860657596044
#     Energy after flip is -0.6288860657596044
#     Spin site 25 has been flipped.
# Spin site 59:
#     Energy before flip is -0.7210077174713919
#     Energy after flip is 0.7210077174713919
#     Spin site 59 has not been flipped.
# Spin site 24:
#     Energy before flip is 1.6969261491659267
#     Energy after flip is -1.6969261491659267
#     Spin site 24 has been flipped.
# Spin site 72:
#     Energy before flip is 0.8062651871247093
#     Energy after flip is -0.8062651871247093
#     Spin site 72 has been flipped.
# Spin site 55:
#     Energy before flip is 1.552894535560684
#     Energy after flip is -1.552894535560684
#     Spin site 55 has been flipped.
# Spin site 87:
#     Energy before flip is -2.0981736432658433
#     Energy after flip is 2.0981736432658433
#     Spin site 87 has not been flipped.
# Spin site 14:
#     Energy before flip is -1.2872437015347526
#     Energy after flip is 1.2872437015347526
#     Spin site 14 has not been flipped.
# Spin site 91:
#     Energy before flip is 0.6999128574493119
#     Energy after flip is -0.6999128574493119
#     Spin site 91 has been flipped.
# Spin site 31:
#     Energy before flip is 1.2589206955950942
#     Energy after flip is -1.2589206955950942
#     Spin site 31 has been flipped.
# Spin site 55:
#     Energy before flip is -1.552894535560684
#     Energy after flip is 1.552894535560684
#     Spin site 55 has not been flipped.
# Spin site 71:
#     Energy before flip is 0.6780091592588047
#     Energy after flip is -0.6780091592588047
#     Spin site 71 has been flipped.
# Spin site 62:
#     Energy before flip is 1.0401021590412254
#     Energy after flip is -1.0401021590412254
#     Spin site 62 has been flipped.
# Spin site 60:
#     Energy before flip is 2.0520043914912067
#     Energy after flip is -2.0520043914912067
#     Spin site 60 has been flipped.
# Spin site 69:
#     Energy before flip is -0.3635272840663121
#     Energy after flip is 0.3635272840663121
#     Spin site 69 has not been flipped.
# Spin site 94:
#     Energy before flip is 0.22189774940523863
#     Energy after flip is -0.22189774940523863
#     Spin site 94 has been flipped.
# Spin site 49:
#     Energy before flip is -1.4404234742937843
#     Energy after flip is 1.4404234742937843
#     Spin site 49 has not been flipped.
# Spin site 60:
#     Energy before flip is -2.0520043914912067
#     Energy after flip is 2.0520043914912067
#     Spin site 60 has not been flipped.
# Spin site 85:
#     Energy before flip is 1.2607554027595567
#     Energy after flip is -1.2607554027595567
#     Spin site 85 has been flipped.
# Spin site 4:
#     Energy before flip is -0.37384193760642126
#     Energy after flip is 0.37384193760642126
#     Spin site 4 has not been flipped.
# Spin site 79:
#     Energy before flip is -0.3162418412304528
#     Energy after flip is 0.3162418412304528
#     Spin site 79 has not been flipped.
# Spin site 56:
#     Energy before flip is -0.7460860850847261
#     Energy after flip is 0.7460860850847261
#     Spin site 56 has not been flipped.
# Spin site 83:
#     Energy before flip is -0.28610880875844424
#     Energy after flip is 0.28610880875844424
#     Spin site 83 has not been flipped.
# Spin site 4:
#     Energy before flip is -0.37384193760642126
#     Energy after flip is 0.37384193760642126
#     Spin site 4 has not been flipped.
# Spin site 1:
#     Energy before flip is -0.5546805015207358
#     Energy after flip is 0.5546805015207358
#     Spin site 1 has not been flipped.
# Spin site 79:
#     Energy before flip is -0.3162418412304528
#     Energy after flip is 0.3162418412304528
#     Spin site 79 has not been flipped.
# Spin site 21:
#     Energy before flip is -0.24602211523024617
#     Energy after flip is 0.24602211523024617
#     Spin site 21 has not been flipped.
# Spin site 32:
#     Energy before flip is -1.0037979327309965
#     Energy after flip is 1.0037979327309965
#     Spin site 32 has not been flipped.
# Spin site 47:
#     Energy before flip is -1.6094345788373585
#     Energy after flip is 1.6094345788373585
#     Spin site 47 has not been flipped.
# Spin site 81:
#     Energy before flip is -0.5174491709467895
#     Energy after flip is 0.5174491709467895
#     Spin site 81 has not been flipped.
# Spin site 26:
#     Energy before flip is -1.2451177900592971
#     Energy after flip is 1.2451177900592971
#     Spin site 26 has not been flipped.
# Spin site 58:
#     Energy before flip is 0.24254917633988693
#     Energy after flip is -0.24254917633988693
#     Spin site 58 has been flipped.
# Spin site 10:
#     Energy before flip is 0.22611703762798185
#     Energy after flip is -0.22611703762798185
#     Spin site 10 has been flipped.
# Spin site 82:
#     Energy before flip is 0.5189256814735055
#     Energy after flip is -0.5189256814735055
#     Spin site 82 has been flipped.
# Spin site 37:
#     Energy before flip is -0.8527852960939277
#     Energy after flip is 0.8527852960939277
#     Spin site 37 has not been flipped.
# Spin site 15:
#     Energy before flip is -1.972139706733949
#     Energy after flip is 1.972139706733949
#     Spin site 15 has not been flipped.
# Spin site 23:
#     Energy before flip is -1.9383887984200043
#     Energy after flip is 1.9383887984200043
#     Spin site 23 has not been flipped.
# Spin site 25:
#     Energy before flip is -1.1157153438187157
#     Energy after flip is 1.1157153438187157
#     Spin site 25 has not been flipped.
# Spin site 39:
#     Energy before flip is -2.575612224233624
#     Energy after flip is 2.575612224233624
#     Spin site 39 has not been flipped.
# Spin site 19:
#     Energy before flip is -2.2816817154026467
#     Energy after flip is 2.2816817154026467
#     Spin site 19 has not been flipped.
# Spin site 67:
#     Energy before flip is -2.281684229985565
#     Energy after flip is 2.281684229985565
#     Spin site 67 has not been flipped.
# Spin site 85:
#     Energy before flip is -1.2607554027595567
#     Energy after flip is 1.2607554027595567
#     Spin site 85 has not been flipped.
# Spin site 23:
#     Energy before flip is -1.9383887984200043
#     Energy after flip is 1.9383887984200043
#     Spin site 23 has not been flipped.
# Spin site 67:
#     Energy before flip is -2.281684229985565
#     Energy after flip is 2.281684229985565
#     Spin site 67 has not been flipped.
# Spin site 12:
#     Energy before flip is -0.8877316829710786
#     Energy after flip is 0.8877316829710786
#     Spin site 12 has not been flipped.
# Spin site 95:
#     Energy before flip is 2.3233001337999495
#     Energy after flip is -2.3233001337999495
#     Spin site 95 has been flipped.
# Spin site 31:
#     Energy before flip is -1.2589206955950942
#     Energy after flip is 1.2589206955950942
#     Spin site 31 has not been flipped.
# Spin site 47:
#     Energy before flip is -1.6094345788373585
#     Energy after flip is 1.6094345788373585
#     Spin site 47 has not been flipped.
# Spin site 81:
#     Energy before flip is -0.4226633638501319
#     Energy after flip is 0.4226633638501319
#     Spin site 81 has not been flipped.
# Spin site 84:
#     Energy before flip is -1.0776955781746074
#     Energy after flip is 1.0776955781746074
#     Spin site 84 has not been flipped.
# Spin site 95:
#     Energy before flip is -2.3233001337999495
#     Energy after flip is 2.3233001337999495
#     Spin site 95 has not been flipped.
# Spin site 67:
#     Energy before flip is -2.281684229985565
#     Energy after flip is 2.281684229985565
#     Spin site 67 has not been flipped.
# Spin site 94:
#     Energy before flip is -0.5158819685502279
#     Energy after flip is 0.5158819685502279
#     Spin site 94 has not been flipped.
# Spin site 72:
#     Energy before flip is -1.4453727477094058
#     Energy after flip is 1.4453727477094058
#     Spin site 72 has not been flipped.
# Spin site 77:
#     Energy before flip is -1.663979490793788
#     Energy after flip is 1.663979490793788
#     Spin site 77 has not been flipped.
# Spin site 98:
#     Energy before flip is -0.6338552262396906
#     Energy after flip is 0.6338552262396906
#     Spin site 98 has not been flipped.
# Spin site 33:
#     Energy before flip is -2.111066410522925
#     Energy after flip is 2.111066410522925
#     Spin site 33 has not been flipped.
# Spin site 85:
#     Energy before flip is -1.2607554027595567
#     Energy after flip is 1.2607554027595567
#     Spin site 85 has not been flipped.
# Spin site 37:
#     Energy before flip is -0.8527852960939277
#     Energy after flip is 0.8527852960939277
#     Spin site 37 has not been flipped.
# Spin site 48:
#     Energy before flip is -1.239542277596577
#     Energy after flip is 1.239542277596577
#     Spin site 48 has not been flipped.
# Spin site 52:
#     Energy before flip is -1.5085391844203349
#     Energy after flip is 1.5085391844203349
#     Spin site 52 has not been flipped.
# Spin site 4:
#     Energy before flip is -0.37384193760642126
#     Energy after flip is 0.37384193760642126
#     Spin site 4 has not been flipped.
# Spin site 77:
#     Energy before flip is -1.663979490793788
#     Energy after flip is 1.663979490793788
#     Spin site 77 has not been flipped.
# Spin site 90:
#     Energy before flip is 0.22117501487287577
#     Energy after flip is -0.22117501487287577
#     Spin site 90 has been flipped.
# Spin site 78:
#     Energy before flip is -0.3754679709932716
#     Energy after flip is 0.3754679709932716
#     Spin site 78 has not been flipped.
# Spin site 12:
#     Energy before flip is -0.8877316829710786
#     Energy after flip is 0.8877316829710786
#     Spin site 12 has not been flipped.
# Spin site 82:
#     Energy before flip is -0.5189256814735055
#     Energy after flip is 0.5189256814735055
#     Spin site 82 has not been flipped.
# Spin site 60:
#     Energy before flip is -2.0520043914912067
#     Energy after flip is 2.0520043914912067
#     Spin site 60 has not been flipped.
# Spin site 20:
#     Energy before flip is -1.0340157469629307
#     Energy after flip is 1.0340157469629307
#     Spin site 20 has not been flipped.
# Spin site 5:
#     Energy before flip is -0.4652021022783923
#     Energy after flip is 0.4652021022783923
#     Spin site 5 has not been flipped.
# Spin site 32:
#     Energy before flip is -1.0037979327309965
#     Energy after flip is 1.0037979327309965
#     Spin site 32 has not been flipped.
# Spin site 23:
#     Energy before flip is -1.9383887984200043
#     Energy after flip is 1.9383887984200043
#     Spin site 23 has not been flipped.
# Spin site 16:
#     Energy before flip is -0.4702827525195432
#     Energy after flip is 0.4702827525195432
#     Spin site 16 has not been flipped.
# Spin site 26:
#     Energy before flip is -1.2451177900592971
#     Energy after flip is 1.2451177900592971
#     Spin site 26 has not been flipped.

# %%
active_dict_1 = {}
for key in spin_dict_1:
    active_dict_1[key] = spin_dict_1[key]
# print(active_dict)
while active_dict_1:
    t = monte_carlo(t, spin_dict_1, active_dict_1)
print("Twin 1 has reached absorbing state.")
# Out:
# n flipped.
# Spin site 22 has been removed from active list
# Spin site 67:
#     Energy before flip is -2.281684229985565
#     Energy after flip is 2.281684229985565
#     Spin site 67 has not been flipped.
# Spin site 67 has been removed from active list
# Spin site 2:
#     Energy before flip is -1.510444635811194
#     Energy after flip is 1.510444635811194
#     Spin site 2 has not been flipped.
# Spin site 2 has been removed from active list
# Spin site 57:
#     Energy before flip is -0.6122094429918058
#     Energy after flip is 0.6122094429918058
#     Spin site 57 has not been flipped.
# Spin site 57 has been removed from active list
# Spin site 44:
#     Energy before flip is 0.4515535017863804
#     Energy after flip is -0.4515535017863804
#     Spin site 44 has been flipped.
# Spin site 66:
#     Energy before flip is -3.5087924141275986
#     Energy after flip is 3.5087924141275986
#     Spin site 66 has not been flipped.
# Spin site 66 has been removed from active list
# Spin site 44:
#     Energy before flip is -0.4515535017863804
#     Energy after flip is 0.4515535017863804
#     Spin site 44 has not been flipped.
# Spin site 44 has been removed from active list
# Spin site 88:
#     Energy before flip is -0.5832691762391251
#     Energy after flip is 0.5832691762391251
#     Spin site 88 has not been flipped.
# Spin site 88 has been removed from active list
# Spin site 43:
#     Energy before flip is -0.4983486106908455
#     Energy after flip is 0.4983486106908455
#     Spin site 43 has not been flipped.
# Spin site 43 has been removed from active list
# Spin site 3:
#     Energy before flip is 0.14616745132486397
#     Energy after flip is -0.14616745132486397
#     Spin site 3 has been flipped.
# Spin site 14:
#     Energy before flip is -1.2872437015347526
#     Energy after flip is 1.2872437015347526
#     Spin site 14 has not been flipped.
# Spin site 14 has been removed from active list
# Spin site 11:
#     Energy before flip is -1.263675750241284
#     Energy after flip is 1.263675750241284
#     Spin site 11 has not been flipped.
# Spin site 11 has been removed from active list
# Spin site 63:
#     Energy before flip is -0.6202942311330525
#     Energy after flip is 0.6202942311330525
#     Spin site 63 has not been flipped.
# Spin site 63 has been removed from active list
# Spin site 96:
#     Energy before flip is -2.6846727152018897
#     Energy after flip is 2.6846727152018897
#     Spin site 96 has not been flipped.
# Spin site 96 has been removed from active list
# Spin site 48:
#     Energy before flip is -1.239542277596577
#     Energy after flip is 1.239542277596577
#     Spin site 48 has not been flipped.
# Spin site 48 has been removed from active list
# Spin site 37:
#     Energy before flip is -0.8527852960939277
#     Energy after flip is 0.8527852960939277
#     Spin site 37 has not been flipped.
# Spin site 37 has been removed from active list
# Spin site 1:
#     Energy before flip is -0.5546805015207358
#     Energy after flip is 0.5546805015207358
#     Spin site 1 has not been flipped.
# Spin site 1 has been removed from active list
# Spin site 94:
#     Energy before flip is -0.5158819685502279
#     Energy after flip is 0.5158819685502279
#     Spin site 94 has not been flipped.
# Spin site 94 has been removed from active list
# Spin site 35:
#     Energy before flip is 0.20728389398813585
#     Energy after flip is -0.20728389398813585
#     Spin site 35 has been flipped.
# Spin site 80:
#     Energy before flip is -1.240924769674217
#     Energy after flip is 1.240924769674217
#     Spin site 80 has not been flipped.
# Spin site 80 has been removed from active list
# Spin site 73:
#     Energy before flip is -0.05949602912988183
#     Energy after flip is 0.05949602912988183
#     Spin site 73 has not been flipped.
# Spin site 73 has been removed from active list
# Spin site 81:
#     Energy before flip is -0.4226633638501319
#     Energy after flip is 0.4226633638501319
#     Spin site 81 has not been flipped.
# Spin site 81 has been removed from active list
# Spin site 45:
#     Energy before flip is -1.5985982507649008
#     Energy after flip is 1.5985982507649008
#     Spin site 45 has not been flipped.
# Spin site 45 has been removed from active list
# Spin site 76:
#     Energy before flip is -1.0912034790643779
#     Energy after flip is 1.0912034790643779
#     Spin site 76 has not been flipped.
# Spin site 76 has been removed from active list
# Spin site 32:
#     Energy before flip is -1.0037979327309965
#     Energy after flip is 1.0037979327309965
#     Spin site 32 has not been flipped.
# Spin site 32 has been removed from active list
# Spin site 25:
#     Energy before flip is -1.1157153438187157
#     Energy after flip is 1.1157153438187157
#     Spin site 25 has not been flipped.
# Spin site 25 has been removed from active list
# Spin site 52:
#     Energy before flip is -1.5085391844203349
#     Energy after flip is 1.5085391844203349
#     Spin site 52 has not been flipped.
# Spin site 52 has been removed from active list
# Spin site 34:
#     Energy before flip is -0.37544638178613254
#     Energy after flip is 0.37544638178613254
#     Spin site 34 has not been flipped.
# Spin site 34 has been removed from active list
# Spin site 58:
#     Energy before flip is -0.24254917633988693
#     Energy after flip is 0.24254917633988693
#     Spin site 58 has not been flipped.
# Spin site 58 has been removed from active list
# Spin site 30:
#     Energy before flip is -3.2563657094751837
#     Energy after flip is 3.2563657094751837
#     Spin site 30 has not been flipped.
# Spin site 30 has been removed from active list
# Spin site 35:
#     Energy before flip is -0.20728389398813585
#     Energy after flip is 0.20728389398813585
#     Spin site 35 has not been flipped.
# Spin site 35 has been removed from active list
# Spin site 42:
#     Energy before flip is -1.5188391934081291
#     Energy after flip is 1.5188391934081291
#     Spin site 42 has not been flipped.
# Spin site 42 has been removed from active list
# Spin site 19:
#     Energy before flip is -2.2816817154026467
#     Energy after flip is 2.2816817154026467
#     Spin site 19 has not been flipped.
# Spin site 19 has been removed from active list
# Spin site 79:
#     Energy before flip is -0.3162418412304528
#     Energy after flip is 0.3162418412304528
#     Spin site 79 has not been flipped.
# Spin site 79 has been removed from active list
# Spin site 77:
#     Energy before flip is -1.663979490793788
#     Energy after flip is 1.663979490793788
#     Spin site 77 has not been flipped.
# Spin site 77 has been removed from active list
# Spin site 31:
#     Energy before flip is -1.2589206955950942
#     Energy after flip is 1.2589206955950942
#     Spin site 31 has not been flipped.
# Spin site 31 has been removed from active list
# Spin site 26:
#     Energy before flip is -1.2451177900592971
#     Energy after flip is 1.2451177900592971
#     Spin site 26 has not been flipped.
# Spin site 26 has been removed from active list
# Spin site 71:
#     Energy before flip is -0.6780091592588047
#     Energy after flip is 0.6780091592588047
#     Spin site 71 has not been flipped.
# Spin site 71 has been removed from active list
# Spin site 87:
#     Energy before flip is 0.8552756967552188
#     Energy after flip is -0.8552756967552188
#     Spin site 87 has been flipped.
# Spin site 72:
#     Energy before flip is -1.4453727477094058
#     Energy after flip is 1.4453727477094058
#     Spin site 72 has not been flipped.
# Spin site 72 has been removed from active list
# Spin site 20:
#     Energy before flip is -1.0340157469629307
#     Energy after flip is 1.0340157469629307
#     Spin site 20 has not been flipped.
# Spin site 20 has been removed from active list
# Spin site 70:
#     Energy before flip is -1.0704979387233642
#     Energy after flip is 1.0704979387233642
#     Spin site 70 has not been flipped.
# Spin site 70 has been removed from active list
# Spin site 3:
#     Energy before flip is -0.14616745132486397
#     Energy after flip is 0.14616745132486397
#     Spin site 3 has not been flipped.
# Spin site 3 has been removed from active list
# Spin site 90:
#     Energy before flip is -0.22117501487287577
#     Energy after flip is 0.22117501487287577
#     Spin site 90 has not been flipped.
# Spin site 90 has been removed from active list
# Spin site 60:
#     Energy before flip is -2.0520043914912067
#     Energy after flip is 2.0520043914912067
#     Spin site 60 has not been flipped.
# Spin site 60 has been removed from active list
# Spin site 49:
#     Energy before flip is -1.4404234742937843
#     Energy after flip is 1.4404234742937843
#     Spin site 49 has not been flipped.
# Spin site 49 has been removed from active list
# Spin site 75:
#     Energy before flip is -1.2734469397123966
#     Energy after flip is 1.2734469397123966
#     Spin site 75 has not been flipped.
# Spin site 75 has been removed from active list
# Spin site 41:
#     Energy before flip is -0.7166324485645968
#     Energy after flip is 0.7166324485645968
#     Spin site 41 has not been flipped.
# Spin site 41 has been removed from active list
# Spin site 51:
#     Energy before flip is -4.050463140210525
#     Energy after flip is 4.050463140210525
#     Spin site 51 has not been flipped.
# Spin site 51 has been removed from active list
# Spin site 10:
#     Energy before flip is -0.22611703762798185
#     Energy after flip is 0.22611703762798185
#     Spin site 10 has not been flipped.
# Spin site 10 has been removed from active list
# Spin site 97:
#     Energy before flip is -0.5389450111568936
#     Energy after flip is 0.5389450111568936
#     Spin site 97 has not been flipped.
# Spin site 97 has been removed from active list
# Spin site 88:
#     Energy before flip is -3.536718516260187
#     Energy after flip is 3.536718516260187
#     Spin site 88 has not been flipped.
# Spin site 88 has been removed from active list
# Spin site 0:
#     Energy before flip is -0.23325990679310124
#     Energy after flip is 0.23325990679310124
#     Spin site 0 has not been flipped.
# Spin site 0 has been removed from active list
# Spin site 89:
#     Energy before flip is -1.9195463691745407
#     Energy after flip is 1.9195463691745407
#     Spin site 89 has not been flipped.
# Spin site 89 has been removed from active list
# Spin site 27:
#     Energy before flip is -0.6500014159612979
#     Energy after flip is 0.6500014159612979
#     Spin site 27 has not been flipped.
# Spin site 27 has been removed from active list
# Spin site 28:
#     Energy before flip is 1.0263861804489096
#     Energy after flip is -1.0263861804489096
#     Spin site 28 has been flipped.
# Spin site 23:
#     Energy before flip is -1.9383887984200043
#     Energy after flip is 1.9383887984200043
#     Spin site 23 has not been flipped.
# Spin site 23 has been removed from active list
# Spin site 29:
#     Energy before flip is -3.1771327810947527
#     Energy after flip is 3.1771327810947527
#     Spin site 29 has not been flipped.
# Spin site 29 has been removed from active list
# Spin site 82:
#     Energy before flip is -0.5189256814735055
#     Energy after flip is 0.5189256814735055
#     Spin site 82 has not been flipped.
# Spin site 82 has been removed from active list
# Spin site 27:
#     Energy before flip is -0.09563275457897585
#     Energy after flip is 0.09563275457897585
#     Spin site 27 has not been flipped.
# Spin site 27 has been removed from active list
# Spin site 17:
#     Energy before flip is -1.6986076652462625
#     Energy after flip is 1.6986076652462625
#     Spin site 17 has not been flipped.
# Spin site 17 has been removed from active list
# Spin site 53:
#     Energy before flip is -1.382026239668836
#     Energy after flip is 1.382026239668836
#     Spin site 53 has not been flipped.
# Spin site 53 has been removed from active list
# Spin site 50:
#     Energy before flip is -3.1420522576673506
#     Energy after flip is 3.1420522576673506
#     Spin site 50 has not been flipped.
# Spin site 50 has been removed from active list
# Spin site 65:
#     Energy before flip is -2.9382001914183618
#     Energy after flip is 2.9382001914183618
#     Spin site 65 has not been flipped.
# Spin site 65 has been removed from active list
# Spin site 87:
#     Energy before flip is -0.8552756967552188
#     Energy after flip is 0.8552756967552188
#     Spin site 87 has not been flipped.
# Spin site 87 has been removed from active list
# Spin site 84:
#     Energy before flip is -1.0776955781746074
#     Energy after flip is 1.0776955781746074
#     Spin site 84 has not been flipped.
# Spin site 84 has been removed from active list
# Spin site 83:
#     Energy before flip is -1.4187459788021128
#     Energy after flip is 1.4187459788021128
#     Spin site 83 has not been flipped.
# Spin site 83 has been removed from active list
# Spin site 69:
#     Energy before flip is -0.3635272840663121
#     Energy after flip is 0.3635272840663121
#     Spin site 69 has not been flipped.
# Spin site 69 has been removed from active list
# Spin site 98:
#     Energy before flip is -0.6338552262396906
#     Energy after flip is 0.6338552262396906
#     Spin site 98 has not been flipped.
# Spin site 98 has been removed from active list
# Spin site 18:
#     Energy before flip is -2.9416080276767467
#     Energy after flip is 2.9416080276767467
#     Spin site 18 has not been flipped.
# Spin site 18 has been removed from active list
# Spin site 4:
#     Energy before flip is -2.5153921165900153
#     Energy after flip is 2.5153921165900153
#     Spin site 4 has not been flipped.
# Spin site 4 has been removed from active list
# Spin site 74:
#     Energy before flip is 0.050194618883944164
#     Energy after flip is -0.050194618883944164
#     Spin site 74 has been flipped.
# Spin site 7:
#     Energy before flip is -1.649251509968261
#     Energy after flip is 1.649251509968261
#     Spin site 7 has not been flipped.
# Spin site 7 has been removed from active list
# Spin site 68:
#     Energy before flip is -0.8837748834248461
#     Energy after flip is 0.8837748834248461
#     Spin site 68 has not been flipped.
# Spin site 68 has been removed from active list
# Spin site 21:
#     Energy before flip is -0.24602211523024617
#     Energy after flip is 0.24602211523024617
#     Spin site 21 has not been flipped.
# Spin site 21 has been removed from active list
# Spin site 12:
#     Energy before flip is -0.8877316829710786
#     Energy after flip is 0.8877316829710786
#     Spin site 12 has not been flipped.
# Spin site 12 has been removed from active list
# Spin site 86:
#     Energy before flip is -0.4140382451099155
#     Energy after flip is 0.4140382451099155
#     Spin site 86 has not been flipped.
# Spin site 86 has been removed from active list
# Spin site 99:
#     Energy before flip is -0.8676913089738585
#     Energy after flip is 0.8676913089738585
#     Spin site 99 has not been flipped.
# Spin site 99 has been removed from active list
# Spin site 64:
#     Energy before flip is -1.3597712976176775
#     Energy after flip is 1.3597712976176775
#     Spin site 64 has not been flipped.
# Spin site 64 has been removed from active list
# Spin site 39:
#     Energy before flip is -2.575612224233624
#     Energy after flip is 2.575612224233624
#     Spin site 39 has not been flipped.
# Spin site 39 has been removed from active list
# Spin site 8:
#     Energy before flip is -1.7443588053940058
#     Energy after flip is 1.7443588053940058
#     Spin site 8 has not been flipped.
# Spin site 8 has been removed from active list
# Spin site 46:
#     Energy before flip is -1.610885459861001
#     Energy after flip is 1.610885459861001
#     Spin site 46 has not been flipped.
# Spin site 46 has been removed from active list
# Spin site 13:
#     Energy before flip is 1.172626572604949
#     Energy after flip is -1.172626572604949
#     Spin site 13 has been flipped.
# Spin site 74:
#     Energy before flip is -0.050194618883944164
#     Energy after flip is 0.050194618883944164
#     Spin site 74 has not been flipped.
# Spin site 74 has been removed from active list
# Spin site 75:
#     Energy before flip is 0.7588096990940665
#     Energy after flip is -0.7588096990940665
#     Spin site 75 has been flipped.
# Spin site 12:
#     Energy before flip is -2.0770751076489438
#     Energy after flip is 2.0770751076489438
#     Spin site 12 has not been flipped.
# Spin site 12 has been removed from active list
# Spin site 6:
#     Energy before flip is -0.12006780386707927
#     Energy after flip is 0.12006780386707927
#     Spin site 6 has not been flipped.
# Spin site 6 has been removed from active list
# Spin site 14:
#     Energy before flip is -2.4431534220667857
#     Energy after flip is 2.4431534220667857
#     Spin site 14 has not been flipped.
# Spin site 14 has been removed from active list
# Spin site 92:
#     Energy before flip is -2.74701727153656
#     Energy after flip is 2.74701727153656
#     Spin site 92 has not been flipped.
# Spin site 92 has been removed from active list
# Spin site 2:
#     Energy before flip is 0.3387706405226717
#     Energy after flip is -0.3387706405226717
#     Spin site 2 has been flipped.
# Spin site 13:
#     Energy before flip is -1.172626572604949
#     Energy after flip is 1.172626572604949
#     Spin site 13 has not been flipped.
# Spin site 13 has been removed from active list
# Spin site 1:
#     Energy before flip is 0.6169934937677867
#     Energy after flip is -0.6169934937677867
#     Spin site 1 has been flipped.
# Spin site 59:
#     Energy before flip is 0.7210077174713919
#     Energy after flip is -0.7210077174713919
#     Spin site 59 has been flipped.
# Spin site 73:
#     Energy before flip is -2.1921419057042333
#     Energy after flip is 2.1921419057042333
#     Spin site 73 has not been flipped.
# Spin site 73 has been removed from active list
# Spin site 1:
#     Energy before flip is -0.6169934937677867
#     Energy after flip is 0.6169934937677867
#     Spin site 1 has not been flipped.
# Spin site 1 has been removed from active list
# Spin site 60:
#     Energy before flip is -3.09448801617115
#     Energy after flip is 3.09448801617115
#     Spin site 60 has not been flipped.
# Spin site 60 has been removed from active list
# Spin site 75:
#     Energy before flip is -0.7588096990940665
#     Energy after flip is 0.7588096990940665
#     Spin site 75 has not been flipped.
# Spin site 75 has been removed from active list
# Spin site 3:
#     Energy before flip is -1.99538272765873
#     Energy after flip is 1.99538272765873
#     Spin site 3 has not been flipped.
# Spin site 3 has been removed from active list
# Spin site 16:
#     Energy before flip is -0.4702827525195432
#     Energy after flip is 0.4702827525195432
#     Spin site 16 has not been flipped.
# Spin site 16 has been removed from active list
# Spin site 2:
#     Energy before flip is -1.510444635811194
#     Energy after flip is 1.510444635811194
#     Spin site 2 has not been flipped.
# Spin site 2 has been removed from active list
# Spin site 0:
#     Energy before flip is -0.29557289904015205
#     Energy after flip is 0.29557289904015205
#     Spin site 0 has not been flipped.
# Spin site 0 has been removed from active list
# Spin site 59:
#     Energy before flip is -0.7210077174713919
#     Energy after flip is 0.7210077174713919
#     Spin site 59 has not been flipped.
# Spin site 59 has been removed from active list
# Spin site 5:
#     Energy before flip is -0.4652021022783923
#     Energy after flip is 0.4652021022783923
#     Spin site 5 has not been flipped.
# Spin site 5 has been removed from active list
# Spin site 74:
#     Energy before flip is -2.0824512576904075
#     Energy after flip is 2.0824512576904075
#     Spin site 74 has not been flipped.
# Spin site 74 has been removed from active list
# Spin site 36:
#     Energy before flip is -1.2569793331071337
#     Energy after flip is 1.2569793331071337
#     Spin site 36 has not been flipped.
# Spin site 36 has been removed from active list
# Spin site 76:
#     Energy before flip is -0.5765662384460477
#     Energy after flip is 0.5765662384460477
#     Spin site 76 has not been flipped.
# Spin site 76 has been removed from active list
# Spin site 15:
#     Energy before flip is -1.972139706733949
#     Energy after flip is 1.972139706733949
#     Spin site 15 has not been flipped.
# Spin site 15 has been removed from active list
# Spin site 58:
#     Energy before flip is -0.6420809866027272
#     Energy after flip is 0.6420809866027272
#     Spin site 58 has not been flipped.
# Spin site 58 has been removed from active list
# Spin site 28:
#     Energy before flip is -1.0263861804489096
#     Energy after flip is 1.0263861804489096
#     Spin site 28 has not been flipped.
# Spin site 28 has been removed from active list
# Twin 1 has reached absorbing state.

# %%
t = 0
while t < switch_time: # t measured in sweeps - one sweep = N spin-flip attempts
    t = glauber(t, spin_dict_2)
# Out:
# Spin site 18:
#     Energy before flip is 0.27107591235694817
#     Energy after flip is -0.27107591235694817
#     Spin site 18 has been flipped.
# Spin site 62:
#     Energy before flip is 1.0401021590412254
#     Energy after flip is -1.0401021590412254
#     Spin site 62 has been flipped.
# Spin site 16:
#     Energy before flip is 0.4702827525195432
#     Energy after flip is -0.4702827525195432
#     Spin site 16 has been flipped.
# Spin site 32:
#     Energy before flip is 1.2515634205818116
#     Energy after flip is -1.2515634205818116
#     Spin site 32 has been flipped.
# Spin site 96:
#     Energy before flip is 1.66794333325302
#     Energy after flip is -1.66794333325302
#     Spin site 96 has been flipped.
# Spin site 61:
#     Energy before flip is 1.272468826466214
#     Energy after flip is -1.272468826466214
#     Spin site 61 has been flipped.
# Spin site 96:
#     Energy before flip is -1.66794333325302
#     Energy after flip is 1.66794333325302
#     Spin site 96 has not been flipped.
# Spin site 79:
#     Energy before flip is 0.3162418412304528
#     Energy after flip is -0.3162418412304528
#     Spin site 79 has been flipped.
# Spin site 40:
#     Energy before flip is -1.6898368009289364
#     Energy after flip is 1.6898368009289364
#     Spin site 40 has not been flipped.
# Spin site 48:
#     Energy before flip is -1.239542277596577
#     Energy after flip is 1.239542277596577
#     Spin site 48 has not been flipped.
# Spin site 35:
#     Energy before flip is 0.20728389398813585
#     Energy after flip is -0.20728389398813585
#     Spin site 35 has been flipped.
# Spin site 88:
#     Energy before flip is 0.5832691762391251
#     Energy after flip is -0.5832691762391251
#     Spin site 88 has been flipped.
# Spin site 50:
#     Energy before flip is -3.1420522576673506
#     Energy after flip is 3.1420522576673506
#     Spin site 50 has not been flipped.
# Spin site 49:
#     Energy before flip is -1.4404234742937843
#     Energy after flip is 1.4404234742937843
#     Spin site 49 has not been flipped.
# Spin site 12:
#     Energy before flip is 0.8877316829710786
#     Energy after flip is -0.8877316829710786
#     Spin site 12 has been flipped.
# Spin site 34:
#     Energy before flip is -0.37544638178613254
#     Energy after flip is 0.37544638178613254
#     Spin site 34 has not been flipped.
# Spin site 91:
#     Energy before flip is 0.6999128574493119
#     Energy after flip is -0.6999128574493119
#     Spin site 91 has been flipped.
# Spin site 37:
#     Energy before flip is -0.8527852960939277
#     Energy after flip is 0.8527852960939277
#     Spin site 37 has not been flipped.
# Spin site 52:
#     Energy before flip is -1.5085391844203349
#     Energy after flip is 1.5085391844203349
#     Spin site 52 has not been flipped.
# Spin site 97:
#     Energy before flip is 0.477784370791976
#     Energy after flip is -0.477784370791976
#     Spin site 97 has been flipped.
# Spin site 31:
#     Energy before flip is 1.2589206955950942
#     Energy after flip is -1.2589206955950942
#     Spin site 31 has been flipped.
# Spin site 27:
#     Energy before flip is -0.6500014159612979
#     Energy after flip is 0.6500014159612979
#     Spin site 27 has not been flipped.
# Spin site 12:
#     Energy before flip is -0.8877316829710786
#     Energy after flip is 0.8877316829710786
#     Spin site 12 has not been flipped.
# Spin site 23:
#     Energy before flip is 0.9686342218527375
#     Energy after flip is -0.9686342218527375
#     Spin site 23 has been flipped.
# Spin site 6:
#     Energy before flip is -0.12006780386707927
#     Energy after flip is 0.12006780386707927
#     Spin site 6 has not been flipped.
# Spin site 66:
#     Energy before flip is -3.5087924141275986
#     Energy after flip is 3.5087924141275986
#     Spin site 66 has not been flipped.
# Spin site 91:
#     Energy before flip is -0.6999128574493119
#     Energy after flip is 0.6999128574493119
#     Spin site 91 has not been flipped.
# Spin site 74:
#     Energy before flip is 0.050194618883944164
#     Energy after flip is -0.050194618883944164
#     Spin site 74 has been flipped.
# Spin site 28:
#     Energy before flip is -1.5807548418312316
#     Energy after flip is 1.5807548418312316
#     Spin site 28 has not been flipped.
# Spin site 35:
#     Energy before flip is -0.20728389398813585
#     Energy after flip is 0.20728389398813585
#     Spin site 35 has not been flipped.
# Spin site 78:
#     Energy before flip is 1.2847212930838787
#     Energy after flip is -1.2847212930838787
#     Spin site 78 has been flipped.
# Spin site 59:
#     Energy before flip is -0.7210077174713919
#     Energy after flip is 0.7210077174713919
#     Spin site 59 has not been flipped.
# Spin site 87:
#     Energy before flip is 0.8552756967552188
#     Energy after flip is -0.8552756967552188
#     Spin site 87 has been flipped.
# Spin site 2:
#     Energy before flip is -0.3387706405226717
#     Energy after flip is 0.3387706405226717
#     Spin site 2 has not been flipped.
# Spin site 67:
#     Energy before flip is 0.18289608824531856
#     Energy after flip is -0.18289608824531856
#     Spin site 67 has been flipped.
# Spin site 40:
#     Energy before flip is -1.6898368009289364
#     Energy after flip is 1.6898368009289364
#     Spin site 40 has not been flipped.
# Spin site 25:
#     Energy before flip is 0.6288860657596044
#     Energy after flip is -0.6288860657596044
#     Spin site 25 has been flipped.
# Spin site 28:
#     Energy before flip is -1.5807548418312316
#     Energy after flip is 1.5807548418312316
#     Spin site 28 has not been flipped.
# Spin site 40:
#     Energy before flip is -1.6898368009289364
#     Energy after flip is 1.6898368009289364
#     Spin site 40 has not been flipped.
# Spin site 11:
#     Energy before flip is -1.701131040378738
#     Energy after flip is 1.701131040378738
#     Spin site 11 has not been flipped.
# Spin site 4:
#     Energy before flip is -0.37384193760642126
#     Energy after flip is 0.37384193760642126
#     Spin site 4 has not been flipped.
# Spin site 13:
#     Energy before flip is 1.172626572604949
#     Energy after flip is -1.172626572604949
#     Spin site 13 has been flipped.
# Spin site 22:
#     Energy before flip is 0.3722234019367482
#     Energy after flip is -0.3722234019367482
#     Spin site 22 has been flipped.
# Spin site 90:
#     Energy before flip is 0.22117501487287577
#     Energy after flip is -0.22117501487287577
#     Spin site 90 has been flipped.
# Spin site 10:
#     Energy before flip is 0.22611703762798185
#     Energy after flip is -0.22611703762798185
#     Spin site 10 has been flipped.
# Spin site 96:
#     Energy before flip is -2.6846727152018897
#     Energy after flip is 2.6846727152018897
#     Spin site 96 has not been flipped.
# Spin site 47:
#     Energy before flip is -1.6094345788373585
#     Energy after flip is 1.6094345788373585
#     Spin site 47 has not been flipped.
# Spin site 62:
#     Energy before flip is 1.561452595688703
#     Energy after flip is -1.561452595688703
#     Spin site 62 has been flipped.
# Spin site 14:
#     Energy before flip is -2.4431534220667857
#     Energy after flip is 2.4431534220667857
#     Spin site 14 has not been flipped.
# Spin site 92:
#     Energy before flip is -2.74701727153656
#     Energy after flip is 2.74701727153656
#     Spin site 92 has not been flipped.
# Spin site 13:
#     Energy before flip is -1.172626572604949
#     Energy after flip is 1.172626572604949
#     Spin site 13 has not been flipped.
# Spin site 89:
#     Energy before flip is -1.9195463691745407
#     Energy after flip is 1.9195463691745407
#     Spin site 89 has not been flipped.
# Spin site 90:
#     Energy before flip is -0.22117501487287577
#     Energy after flip is 0.22117501487287577
#     Spin site 90 has not been flipped.
# Spin site 84:
#     Energy before flip is -0.6271592093859497
#     Energy after flip is 0.6271592093859497
#     Spin site 84 has not been flipped.
# Spin site 37:
#     Energy before flip is -0.8527852960939277
#     Energy after flip is 0.8527852960939277
#     Spin site 37 has not been flipped.
# Spin site 1:
#     Energy before flip is 0.5546805015207358
#     Energy after flip is -0.5546805015207358
#     Spin site 1 has been flipped.
# Spin site 43:
#     Energy before flip is 0.6439581348345851
#     Energy after flip is -0.6439581348345851
#     Spin site 43 has been flipped.
# Spin site 2:
#     Energy before flip is -1.510444635811194
#     Energy after flip is 1.510444635811194
#     Spin site 2 has not been flipped.
# Spin site 14:
#     Energy before flip is -2.4431534220667857
#     Energy after flip is 2.4431534220667857
#     Spin site 14 has not been flipped.
# Spin site 65:
#     Energy before flip is -2.9382001914183618
#     Energy after flip is 2.9382001914183618
#     Spin site 65 has not been flipped.
# Spin site 95:
#     Energy before flip is -2.3233001337999495
#     Energy after flip is 2.3233001337999495
#     Spin site 95 has not been flipped.
# Spin site 20:
#     Energy before flip is 1.0340157469629307
#     Energy after flip is -1.0340157469629307
#     Spin site 20 has been flipped.
# Spin site 76:
#     Energy before flip is -1.0912034790643779
#     Energy after flip is 1.0912034790643779
#     Spin site 76 has not been flipped.
# Spin site 51:
#     Energy before flip is -4.050463140210525
#     Energy after flip is 4.050463140210525
#     Spin site 51 has not been flipped.
# Spin site 47:
#     Energy before flip is -1.6094345788373585
#     Energy after flip is 1.6094345788373585
#     Spin site 47 has not been flipped.
# Spin site 88:
#     Energy before flip is -3.536718516260187
#     Energy after flip is 3.536718516260187
#     Spin site 88 has not been flipped.
# Spin site 6:
#     Energy before flip is -0.12006780386707927
#     Energy after flip is 0.12006780386707927
#     Spin site 6 has not been flipped.
# Spin site 76:
#     Energy before flip is -1.0912034790643779
#     Energy after flip is 1.0912034790643779
#     Spin site 76 has not been flipped.
# Spin site 45:
#     Energy before flip is -0.5498817230484004
#     Energy after flip is 0.5498817230484004
#     Spin site 45 has not been flipped.
# Spin site 46:
#     Energy before flip is -1.610885459861001
#     Energy after flip is 1.610885459861001
#     Spin site 46 has not been flipped.
# Spin site 44:
#     Energy before flip is 0.4515535017863804
#     Energy after flip is -0.4515535017863804
#     Spin site 44 has been flipped.
# Spin site 16:
#     Energy before flip is -0.4702827525195432
#     Energy after flip is 0.4702827525195432
#     Spin site 16 has not been flipped.
# Spin site 5:
#     Energy before flip is -0.4652021022783923
#     Energy after flip is 0.4652021022783923
#     Spin site 5 has not been flipped.
# Spin site 37:
#     Energy before flip is -0.8527852960939277
#     Energy after flip is 0.8527852960939277
#     Spin site 37 has not been flipped.
# Spin site 55:
#     Energy before flip is 1.552894535560684
#     Energy after flip is -1.552894535560684
#     Spin site 55 has been flipped.
# Spin site 30:
#     Energy before flip is 0.4907588304341801
#     Energy after flip is -0.4907588304341801
#     Spin site 30 has been flipped.
# Spin site 25:
#     Energy before flip is -0.6288860657596044
#     Energy after flip is 0.6288860657596044
#     Spin site 25 has not been flipped.
# Spin site 51:
#     Energy before flip is -4.050463140210525
#     Energy after flip is 4.050463140210525
#     Spin site 51 has not been flipped.
# Spin site 60:
#     Energy before flip is -3.09448801617115
#     Energy after flip is 3.09448801617115
#     Spin site 60 has not been flipped.
# Spin site 79:
#     Energy before flip is -1.2254951633210598
#     Energy after flip is 1.2254951633210598
#     Spin site 79 has not been flipped.
# Spin site 89:
#     Energy before flip is -1.9195463691745407
#     Energy after flip is 1.9195463691745407
#     Spin site 89 has not been flipped.
# Spin site 79:
#     Energy before flip is -1.2254951633210598
#     Energy after flip is 1.2254951633210598
#     Spin site 79 has not been flipped.
# Spin site 30:
#     Energy before flip is -0.4907588304341801
#     Energy after flip is 0.4907588304341801
#     Spin site 30 has not been flipped.
# Spin site 19:
#     Energy before flip is -2.2816817154026467
#     Energy after flip is 2.2816817154026467
#     Spin site 19 has not been flipped.
# Spin site 60:
#     Energy before flip is -3.09448801617115
#     Energy after flip is 3.09448801617115
#     Spin site 60 has not been flipped.
# Spin site 69:
#     Energy before flip is 0.3635272840663121
#     Energy after flip is -0.3635272840663121
#     Spin site 69 has been flipped.
# Spin site 68:
#     Energy before flip is -0.8837748834248461
#     Energy after flip is 0.8837748834248461
#     Spin site 68 has not been flipped.
# Spin site 65:
#     Energy before flip is -2.9382001914183618
#     Energy after flip is 2.9382001914183618
#     Spin site 65 has not been flipped.
# Spin site 84:
#     Energy before flip is -0.6271592093859497
#     Energy after flip is 0.6271592093859497
#     Spin site 84 has not been flipped.
# Spin site 92:
#     Energy before flip is -2.74701727153656
#     Energy after flip is 2.74701727153656
#     Spin site 92 has not been flipped.
# Spin site 69:
#     Energy before flip is -0.3635272840663121
#     Energy after flip is 0.3635272840663121
#     Spin site 69 has not been flipped.
# Spin site 53:
#     Energy before flip is -1.382026239668836
#     Energy after flip is 1.382026239668836
#     Spin site 53 has not been flipped.
# Spin site 96:
#     Energy before flip is -2.6846727152018897
#     Energy after flip is 2.6846727152018897
#     Spin site 96 has not been flipped.
# Spin site 67:
#     Energy before flip is -0.18289608824531856
#     Energy after flip is 0.18289608824531856
#     Spin site 67 has not been flipped.
# Spin site 48:
#     Energy before flip is -1.239542277596577
#     Energy after flip is 1.239542277596577
#     Spin site 48 has not been flipped.
# Spin site 15:
#     Energy before flip is -1.972139706733949
#     Energy after flip is 1.972139706733949
#     Spin site 15 has not been flipped.
# Spin site 22:
#     Energy before flip is -0.3722234019367482
#     Energy after flip is 0.3722234019367482
#     Spin site 22 has not been flipped.
# Spin site 43:
#     Energy before flip is -0.4983486106908455
#     Energy after flip is 0.4983486106908455
#     Spin site 43 has not been flipped.
# Spin site 13:
#     Energy before flip is -1.172626572604949
#     Energy after flip is 1.172626572604949
#     Spin site 13 has not been flipped.
# Spin site 1:
#     Energy before flip is -0.5546805015207358
#     Energy after flip is 0.5546805015207358
#     Spin site 1 has not been flipped.

# %%
active_dict_2 = {}
for key in spin_dict_2:
    active_dict_2[key] = spin_dict_1[key]
# print(active_dict)
while active_dict_2:
    t = monte_carlo(t, spin_dict_2, active_dict_2)
print("Twin 2 has reached absorbing state.")
# Out:
# oved from active list
# Spin site 77:
#     Energy before flip is -1.663979490793788
#     Energy after flip is 1.663979490793788
#     Spin site 77 has not been flipped.
# Spin site 77 has been removed from active list
# Spin site 63:
#     Energy before flip is -1.1416446677805303
#     Energy after flip is 1.1416446677805303
#     Spin site 63 has not been flipped.
# Spin site 63 has been removed from active list
# Spin site 96:
#     Energy before flip is -2.6846727152018897
#     Energy after flip is 2.6846727152018897
#     Spin site 96 has not been flipped.
# Spin site 96 has been removed from active list
# Spin site 88:
#     Energy before flip is -3.536718516260187
#     Energy after flip is 3.536718516260187
#     Spin site 88 has not been flipped.
# Spin site 88 has been removed from active list
# Spin site 57:
#     Energy before flip is 0.2724207199508083
#     Energy after flip is -0.2724207199508083
#     Spin site 57 has been flipped.
# Spin site 43:
#     Energy before flip is -0.4983486106908455
#     Energy after flip is 0.4983486106908455
#     Spin site 43 has not been flipped.
# Spin site 43 has been removed from active list
# Spin site 58:
#     Energy before flip is -0.6420809866027272
#     Energy after flip is 0.6420809866027272
#     Spin site 58 has not been flipped.
# Spin site 58 has been removed from active list
# Spin site 28:
#     Energy before flip is -1.5807548418312316
#     Energy after flip is 1.5807548418312316
#     Spin site 28 has not been flipped.
# Spin site 28 has been removed from active list
# Spin site 35:
#     Energy before flip is -0.20728389398813585
#     Energy after flip is 0.20728389398813585
#     Spin site 35 has not been flipped.
# Spin site 35 has been removed from active list
# Spin site 33:
#     Energy before flip is -2.111066410522925
#     Energy after flip is 2.111066410522925
#     Spin site 33 has not been flipped.
# Spin site 33 has been removed from active list
# Spin site 26:
#     Energy before flip is -1.2451177900592971
#     Energy after flip is 1.2451177900592971
#     Spin site 26 has not been flipped.
# Spin site 26 has been removed from active list
# Spin site 90:
#     Energy before flip is -0.22117501487287577
#     Energy after flip is 0.22117501487287577
#     Spin site 90 has not been flipped.
# Spin site 90 has been removed from active list
# Spin site 19:
#     Energy before flip is -2.2816817154026467
#     Energy after flip is 2.2816817154026467
#     Spin site 19 has not been flipped.
# Spin site 19 has been removed from active list
# Spin site 84:
#     Energy before flip is -0.6271592093859497
#     Energy after flip is 0.6271592093859497
#     Spin site 84 has not been flipped.
# Spin site 84 has been removed from active list
# Spin site 75:
#     Energy before flip is 0.7588096990940665
#     Energy after flip is -0.7588096990940665
#     Spin site 75 has been flipped.
# Spin site 37:
#     Energy before flip is -0.8527852960939277
#     Energy after flip is 0.8527852960939277
#     Spin site 37 has not been flipped.
# Spin site 37 has been removed from active list
# Spin site 36:
#     Energy before flip is -1.2569793331071337
#     Energy after flip is 1.2569793331071337
#     Spin site 36 has not been flipped.
# Spin site 36 has been removed from active list
# Spin site 4:
#     Energy before flip is -0.37384193760642126
#     Energy after flip is 0.37384193760642126
#     Spin site 4 has not been flipped.
# Spin site 4 has been removed from active list
# Spin site 56:
#     Energy before flip is -0.40629736204372857
#     Energy after flip is 0.40629736204372857
#     Spin site 56 has not been flipped.
# Spin site 56 has been removed from active list
# Spin site 47:
#     Energy before flip is -1.6094345788373585
#     Energy after flip is 1.6094345788373585
#     Spin site 47 has not been flipped.
# Spin site 47 has been removed from active list
# Spin site 73:
#     Energy before flip is 0.05949602912988183
#     Energy after flip is -0.05949602912988183
#     Spin site 73 has been flipped.
# Spin site 93:
#     Energy before flip is -2.0543717811169904
#     Energy after flip is 2.0543717811169904
#     Spin site 93 has not been flipped.
# Spin site 93 has been removed from active list
# Spin site 42:
#     Energy before flip is -1.5188391934081291
#     Energy after flip is 1.5188391934081291
#     Spin site 42 has not been flipped.
# Spin site 42 has been removed from active list
# Spin site 66:
#     Energy before flip is -1.4100042723873523
#     Energy after flip is 1.4100042723873523
#     Spin site 66 has not been flipped.
# Spin site 66 has been removed from active list
# Spin site 7:
#     Energy before flip is -1.649251509968261
#     Energy after flip is 1.649251509968261
#     Spin site 7 has not been flipped.
# Spin site 7 has been removed from active list
# Spin site 3:
#     Energy before flip is 0.14616745132486397
#     Energy after flip is -0.14616745132486397
#     Spin site 3 has been flipped.
# Spin site 94:
#     Energy before flip is -0.22189774940523863
#     Energy after flip is 0.22189774940523863
#     Spin site 94 has not been flipped.
# Spin site 94 has been removed from active list
# Spin site 23:
#     Energy before flip is -1.9383887984200043
#     Energy after flip is 1.9383887984200043
#     Spin site 23 has not been flipped.
# Spin site 23 has been removed from active list
# Spin site 17:
#     Energy before flip is 0.9719244500735357
#     Energy after flip is -0.9719244500735357
#     Spin site 17 has been flipped.
# Spin site 69:
#     Energy before flip is -0.3635272840663121
#     Energy after flip is 0.3635272840663121
#     Spin site 69 has not been flipped.
# Spin site 69 has been removed from active list
# Spin site 73:
#     Energy before flip is -0.05949602912988183
#     Energy after flip is 0.05949602912988183
#     Spin site 73 has not been flipped.
# Spin site 73 has been removed from active list
# Spin site 22:
#     Energy before flip is -0.3722234019367482
#     Energy after flip is 0.3722234019367482
#     Spin site 22 has not been flipped.
# Spin site 22 has been removed from active list
# Spin site 24:
#     Energy before flip is -1.2100968711068152
#     Energy after flip is 1.2100968711068152
#     Spin site 24 has not been flipped.
# Spin site 24 has been removed from active list
# Spin site 39:
#     Energy before flip is -2.575612224233624
#     Energy after flip is 2.575612224233624
#     Spin site 39 has not been flipped.
# Spin site 39 has been removed from active list
# Spin site 85:
#     Energy before flip is 1.2607554027595567
#     Energy after flip is -1.2607554027595567
#     Spin site 85 has been flipped.
# Spin site 62:
#     Energy before flip is -1.561452595688703
#     Energy after flip is 1.561452595688703
#     Spin site 62 has not been flipped.
# Spin site 62 has been removed from active list
# Spin site 20:
#     Energy before flip is -1.0340157469629307
#     Energy after flip is 1.0340157469629307
#     Spin site 20 has not been flipped.
# Spin site 20 has been removed from active list
# Spin site 64:
#     Energy before flip is -1.3597712976176775
#     Energy after flip is 1.3597712976176775
#     Spin site 64 has not been flipped.
# Spin site 64 has been removed from active list
# Spin site 97:
#     Energy before flip is -0.477784370791976
#     Energy after flip is 0.477784370791976
#     Spin site 97 has not been flipped.
# Spin site 97 has been removed from active list
# Spin site 18:
#     Energy before flip is -2.9416080276767467
#     Energy after flip is 2.9416080276767467
#     Spin site 18 has not been flipped.
# Spin site 18 has been removed from active list
# Spin site 89:
#     Energy before flip is -1.9195463691745407
#     Energy after flip is 1.9195463691745407
#     Spin site 89 has not been flipped.
# Spin site 89 has been removed from active list
# Spin site 71:
#     Energy before flip is -0.6780091592588047
#     Energy after flip is 0.6780091592588047
#     Spin site 71 has not been flipped.
# Spin site 71 has been removed from active list
# Spin site 1:
#     Energy before flip is -0.5546805015207358
#     Energy after flip is 0.5546805015207358
#     Spin site 1 has not been flipped.
# Spin site 1 has been removed from active list
# Spin site 67:
#     Energy before flip is -0.18289608824531856
#     Energy after flip is 0.18289608824531856
#     Spin site 67 has not been flipped.
# Spin site 67 has been removed from active list
# Spin site 4:
#     Energy before flip is -2.5153921165900153
#     Energy after flip is 2.5153921165900153
#     Spin site 4 has not been flipped.
# Spin site 4 has been removed from active list
# Spin site 38:
#     Energy before flip is -1.065751260279189
#     Energy after flip is 1.065751260279189
#     Spin site 38 has not been flipped.
# Spin site 38 has been removed from active list
# Spin site 78:
#     Energy before flip is -1.2847212930838787
#     Energy after flip is 1.2847212930838787
#     Spin site 78 has not been flipped.
# Spin site 78 has been removed from active list
# Spin site 91:
#     Energy before flip is -1.423157841345294
#     Energy after flip is 1.423157841345294
#     Spin site 91 has not been flipped.
# Spin site 91 has been removed from active list
# Spin site 6:
#     Energy before flip is -0.12006780386707927
#     Energy after flip is 0.12006780386707927
#     Spin site 6 has not been flipped.
# Spin site 6 has been removed from active list
# Spin site 3:
#     Energy before flip is -0.14616745132486397
#     Energy after flip is 0.14616745132486397
#     Spin site 3 has not been flipped.
# Spin site 3 has been removed from active list
# Spin site 82:
#     Energy before flip is 0.5189256814735055
#     Energy after flip is -0.5189256814735055
#     Spin site 82 has been flipped.
# Spin site 55:
#     Energy before flip is -1.552894535560684
#     Energy after flip is 1.552894535560684
#     Spin site 55 has not been flipped.
# Spin site 55 has been removed from active list
# Spin site 25:
#     Energy before flip is -0.6288860657596044
#     Energy after flip is 0.6288860657596044
#     Spin site 25 has not been flipped.
# Spin site 25 has been removed from active list
# Spin site 30:
#     Energy before flip is -0.4907588304341801
#     Energy after flip is 0.4907588304341801
#     Spin site 30 has not been flipped.
# Spin site 30 has been removed from active list
# Spin site 85:
#     Energy before flip is -1.2607554027595567
#     Energy after flip is 1.2607554027595567
#     Spin site 85 has not been flipped.
# Spin site 85 has been removed from active list
# Spin site 61:
#     Energy before flip is -3.8740235811961425
#     Energy after flip is 3.8740235811961425
#     Spin site 61 has not been flipped.
# Spin site 61 has been removed from active list
# Spin site 95:
#     Energy before flip is -2.02931591465496
#     Energy after flip is 2.02931591465496
#     Spin site 95 has not been flipped.
# Spin site 95 has been removed from active list
# Spin site 12:
#     Energy before flip is -2.0770751076489438
#     Energy after flip is 2.0770751076489438
#     Spin site 12 has not been flipped.
# Spin site 12 has been removed from active list
# Spin site 65:
#     Energy before flip is -2.9382001914183618
#     Energy after flip is 2.9382001914183618
#     Spin site 65 has not been flipped.
# Spin site 65 has been removed from active list
# Spin site 70:
#     Energy before flip is -1.0704979387233642
#     Energy after flip is 1.0704979387233642
#     Spin site 70 has not been flipped.
# Spin site 70 has been removed from active list
# Spin site 29:
#     Energy before flip is -3.1771327810947527
#     Energy after flip is 3.1771327810947527
#     Spin site 29 has not been flipped.
# Spin site 29 has been removed from active list
# Spin site 59:
#     Energy before flip is -0.7210077174713919
#     Energy after flip is 0.7210077174713919
#     Spin site 59 has not been flipped.
# Spin site 59 has been removed from active list
# Spin site 81:
#     Energy before flip is 0.5174491709467895
#     Energy after flip is -0.5174491709467895
#     Spin site 81 has been flipped.
# Spin site 80:
#     Energy before flip is -1.240924769674217
#     Energy after flip is 1.240924769674217
#     Spin site 80 has not been flipped.
# Spin site 80 has been removed from active list
# Spin site 15:
#     Energy before flip is -1.972139706733949
#     Energy after flip is 1.972139706733949
#     Spin site 15 has not been flipped.
# Spin site 15 has been removed from active list
# Spin site 52:
#     Energy before flip is -1.5085391844203349
#     Energy after flip is 1.5085391844203349
#     Spin site 52 has not been flipped.
# Spin site 52 has been removed from active list
# Spin site 92:
#     Energy before flip is -2.74701727153656
#     Energy after flip is 2.74701727153656
#     Spin site 92 has not been flipped.
# Spin site 92 has been removed from active list
# Spin site 45:
#     Energy before flip is -1.5985982507649008
#     Energy after flip is 1.5985982507649008
#     Spin site 45 has not been flipped.
# Spin site 45 has been removed from active list
# Spin site 74:
#     Energy before flip is 0.050194618883944164
#     Energy after flip is -0.050194618883944164
#     Spin site 74 has been flipped.
# Spin site 40:
#     Energy before flip is -1.6898368009289364
#     Energy after flip is 1.6898368009289364
#     Spin site 40 has not been flipped.
# Spin site 40 has been removed from active list
# Spin site 99:
#     Energy before flip is -0.8676913089738585
#     Energy after flip is 0.8676913089738585
#     Spin site 99 has not been flipped.
# Spin site 99 has been removed from active list
# Spin site 76:
#     Energy before flip is -0.5765662384460477
#     Energy after flip is 0.5765662384460477
#     Spin site 76 has not been flipped.
# Spin site 76 has been removed from active list
# Spin site 75:
#     Energy before flip is 1.2734469397123966
#     Energy after flip is -1.2734469397123966
#     Spin site 75 has been flipped.
# Spin site 83:
#     Energy before flip is -1.4187459788021128
#     Energy after flip is 1.4187459788021128
#     Spin site 83 has not been flipped.
# Spin site 83 has been removed from active list
# Spin site 27:
#     Energy before flip is -0.6500014159612979
#     Energy after flip is 0.6500014159612979
#     Spin site 27 has not been flipped.
# Spin site 27 has been removed from active list
# Spin site 82:
#     Energy before flip is -0.6137114885701631
#     Energy after flip is 0.6137114885701631
#     Spin site 82 has not been flipped.
# Spin site 82 has been removed from active list
# Spin site 76:
#     Energy before flip is -1.0912034790643779
#     Energy after flip is 1.0912034790643779
#     Spin site 76 has not been flipped.
# Spin site 76 has been removed from active list
# Spin site 72:
#     Energy before flip is -1.4453727477094058
#     Energy after flip is 1.4453727477094058
#     Spin site 72 has not been flipped.
# Spin site 72 has been removed from active list
# Spin site 49:
#     Energy before flip is -1.4404234742937843
#     Energy after flip is 1.4404234742937843
#     Spin site 49 has not been flipped.
# Spin site 49 has been removed from active list
# Spin site 16:
#     Energy before flip is 0.2564004626531837
#     Energy after flip is -0.2564004626531837
#     Spin site 16 has been flipped.
# Spin site 17:
#     Energy before flip is -1.6986076652462625
#     Energy after flip is 1.6986076652462625
#     Spin site 17 has not been flipped.
# Spin site 17 has been removed from active list
# Spin site 21:
#     Energy before flip is -0.24602211523024617
#     Energy after flip is 0.24602211523024617
#     Spin site 21 has not been flipped.
# Spin site 21 has been removed from active list
# Spin site 13:
#     Energy before flip is -1.172626572604949
#     Energy after flip is 1.172626572604949
#     Spin site 13 has not been flipped.
# Spin site 13 has been removed from active list
# Spin site 5:
#     Energy before flip is -0.4652021022783923
#     Energy after flip is 0.4652021022783923
#     Spin site 5 has not been flipped.
# Spin site 5 has been removed from active list
# Spin site 84:
#     Energy before flip is -1.0776955781746074
#     Energy after flip is 1.0776955781746074
#     Spin site 84 has not been flipped.
# Spin site 84 has been removed from active list
# Spin site 34:
#     Energy before flip is -0.37544638178613254
#     Energy after flip is 0.37544638178613254
#     Spin site 34 has not been flipped.
# Spin site 34 has been removed from active list
# Spin site 57:
#     Energy before flip is -0.2724207199508083
#     Energy after flip is 0.2724207199508083
#     Spin site 57 has not been flipped.
# Spin site 57 has been removed from active list
# Spin site 15:
#     Energy before flip is -1.7582574168675893
#     Energy after flip is 1.7582574168675893
#     Spin site 15 has not been flipped.
# Spin site 15 has been removed from active list
# Spin site 86:
#     Energy before flip is -0.4140382451099155
#     Energy after flip is 0.4140382451099155
#     Spin site 86 has not been flipped.
# Spin site 86 has been removed from active list
# Spin site 2:
#     Energy before flip is 0.3387706405226717
#     Energy after flip is -0.3387706405226717
#     Spin site 2 has been flipped.
# Spin site 3:
#     Energy before flip is -1.99538272765873
#     Energy after flip is 1.99538272765873
#     Spin site 3 has not been flipped.
# Spin site 3 has been removed from active list
# Spin site 8:
#     Energy before flip is -1.7443588053940058
#     Energy after flip is 1.7443588053940058
#     Spin site 8 has not been flipped.
# Spin site 8 has been removed from active list
# Spin site 1:
#     Energy before flip is 0.6169934937677867
#     Energy after flip is -0.6169934937677867
#     Spin site 1 has been flipped.
# Spin site 31:
#     Energy before flip is 1.5066861834459093
#     Energy after flip is -1.5066861834459093
#     Spin site 31 has been flipped.
# Spin site 74:
#     Energy before flip is -2.0824512576904075
#     Energy after flip is 2.0824512576904075
#     Spin site 74 has not been flipped.
# Spin site 74 has been removed from active list
# Spin site 11:
#     Energy before flip is -1.263675750241284
#     Energy after flip is 1.263675750241284
#     Spin site 11 has not been flipped.
# Spin site 11 has been removed from active list
# Spin site 16:
#     Energy before flip is -0.2564004626531837
#     Energy after flip is 0.2564004626531837
#     Spin site 16 has not been flipped.
# Spin site 16 has been removed from active list
# Spin site 30:
#     Energy before flip is -3.2563657094751837
#     Energy after flip is 3.2563657094751837
#     Spin site 30 has not been flipped.
# Spin site 30 has been removed from active list
# Spin site 31:
#     Energy before flip is -1.5066861834459093
#     Energy after flip is 1.5066861834459093
#     Spin site 31 has not been flipped.
# Spin site 31 has been removed from active list
# Spin site 75:
#     Energy before flip is -1.2734469397123966
#     Energy after flip is 1.2734469397123966
#     Spin site 75 has not been flipped.
# Spin site 75 has been removed from active list
# Spin site 2:
#     Energy before flip is -1.510444635811194
#     Energy after flip is 1.510444635811194
#     Spin site 2 has not been flipped.
# Spin site 2 has been removed from active list
# Spin site 1:
#     Energy before flip is -0.6169934937677867
#     Energy after flip is 0.6169934937677867
#     Spin site 1 has not been flipped.
# Spin site 1 has been removed from active list
# Spin site 81:
#     Energy before flip is -0.5174491709467895
#     Energy after flip is 0.5174491709467895
#     Spin site 81 has not been flipped.
# Spin site 81 has been removed from active list
# Spin site 51:
#     Energy before flip is -4.050463140210525
#     Energy after flip is 4.050463140210525
#     Spin site 51 has not been flipped.
# Spin site 51 has been removed from active list
# Spin site 44:
#     Energy before flip is -0.4515535017863804
#     Energy after flip is 0.4515535017863804
#     Spin site 44 has not been flipped.
# Spin site 44 has been removed from active list
# Spin site 0:
#     Energy before flip is -0.29557289904015205
#     Energy after flip is 0.29557289904015205
#     Spin site 0 has not been flipped.
# Spin site 0 has been removed from active list
# Spin site 32:
#     Energy before flip is -1.2515634205818116
#     Energy after flip is 1.2515634205818116
#     Spin site 32 has not been flipped.
# Spin site 32 has been removed from active list
# Spin site 54:
#     Energy before flip is -3.0322710523683476
#     Energy after flip is 3.0322710523683476
#     Spin site 54 has not been flipped.
# Spin site 54 has been removed from active list
# Spin site 73:
#     Energy before flip is -2.1921419057042333
#     Energy after flip is 2.1921419057042333
#     Spin site 73 has not been flipped.
# Spin site 73 has been removed from active list
# Twin 2 has reached absorbing state.

# %%
def q_infinity(N):
    overlap = 0
    for spin in spin_dict_1:
        overlap += spin_dict_1[spin]*spin_dict_2[spin]
    overlap = overlap/N
    return overlap

# %%
q = q_infinity(100)
print(q)
# Out:
# 0.32

# %%
q_list = []
q_list.append(q)
# q_list.append(0.49)

# %%
print(q_list)
# Out:
# [0.32, 0.49]

# %%
print(np.mean(q_list))
# Out:
# 0.405
