# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import csv

# %%
fields = ['Spin test #', 'q (spin overlap)']
rows = [[0, 0.52]]

# %%
with open('spin.csv', 'w') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(fields)
    csvwriter.writerows(rows)

# %%
spin_num = 100 # number of spin-sites
s = np.random.normal(0, 1, spin_num)

# %%
neighbor_cable =  [[] for y in range(spin_num)] 
for i in range(1, len(neighbor_cable)-1):
    neighbor_cable[i] = [i-1, i+1]
neighbor_cable[0] = [spin_num-1, 1]
neighbor_cable[spin_num-1] = [spin_num-2, 0]

# %%
spin_dict_1 = {} # list of spins
spin_dict_2 = {}
for i in range(0, 100):
    random.seed()
    spin_dict_1[i] = random.choice([-1,1])

for key in spin_dict_1:
    spin_dict_2[key] = spin_dict_1[key]

# %%
def hamiltonian(spin, dict, flip = False): #compute energy given a spin site number
    sum = 0
    spin_value = dict[spin]
    prev_neighbor = neighbor_cable[spin][0]
    next_neighbor = neighbor_cable[spin][1]
    if flip == True:
        spin_value = -spin_value
    sum -= s[prev_neighbor]*dict[prev_neighbor]*spin_value
    sum -= s[spin]*spin_value*dict[next_neighbor]
    return sum

# %%
def flip_check(spin, dict):
    energy_unflipped = hamiltonian(spin, dict)
    energy_flipped = hamiltonian(spin, dict, flip = True)

    print(f"Spin site {spin}:")
    print(f"    Energy before flip is {energy_unflipped}")
    print(f"    Energy after flip is {energy_flipped}")

    if energy_flipped < energy_unflipped:
        dict[spin] = dict[spin] * (-1)
        print(f"    Spin site {spin} has been flipped.")
        return True
    else:
        print(f"    Spin site {spin} has not been flipped.")
        return False

# %%
def glauber(t, dict):
    t += 1/spin_num
    random.seed()
    spin = random.randint(0, spin_num-1)
    flip_check(spin, dict)
    return t

# %%
def monte_carlo(t, dict, active_dict):
    random.seed()
    spin = random.choice(list(active_dict.keys()))
    prev_neighbor = neighbor_cable[spin][0]
    next_neighbor = neighbor_cable[spin][1]
    
    t += 1/len(active_dict)
    if not flip_check(spin, dict):
        active_dict.pop(spin)
        print(f"Spin site {spin} has been removed from active list")
    else: # spin has been flipped, neighbor sites are now active
        active_dict[spin] = active_dict[spin] * (-1)
        if spin - 1 not in active_dict.keys():
            active_dict[prev_neighbor] = dict[prev_neighbor]
        if spin + 1 not in active_dict.keys():
            active_dict[next_neighbor] = dict[next_neighbor]
    return t

# %%
switch_time = 1

# %%
t = 0
while t < switch_time: # t measured in sweeps - one sweep = N spin-flip attempts
    t = glauber(t, spin_dict_1)
# Out:
# Spin site 0:
#     Energy before flip is -4.288086695010205
#     Energy after flip is 4.288086695010205
#     Spin site 0 has not been flipped.
# Spin site 19:
#     Energy before flip is 0.7354802201132203
#     Energy after flip is -0.7354802201132203
#     Spin site 19 has been flipped.
# Spin site 40:
#     Energy before flip is -2.0752537691061748
#     Energy after flip is 2.0752537691061748
#     Spin site 40 has not been flipped.
# Spin site 11:
#     Energy before flip is -0.0852413312716716
#     Energy after flip is 0.0852413312716716
#     Spin site 11 has not been flipped.
# Spin site 38:
#     Energy before flip is -0.921173479408916
#     Energy after flip is 0.921173479408916
#     Spin site 38 has not been flipped.
# Spin site 5:
#     Energy before flip is -1.6352544019558
#     Energy after flip is 1.6352544019558
#     Spin site 5 has not been flipped.
# Spin site 73:
#     Energy before flip is -2.315079371590645
#     Energy after flip is 2.315079371590645
#     Spin site 73 has not been flipped.
# Spin site 96:
#     Energy before flip is 0.5701364358378891
#     Energy after flip is -0.5701364358378891
#     Spin site 96 has been flipped.
# Spin site 48:
#     Energy before flip is 1.8074375877140652
#     Energy after flip is -1.8074375877140652
#     Spin site 48 has been flipped.
# Spin site 94:
#     Energy before flip is 0.1627639628399985
#     Energy after flip is -0.1627639628399985
#     Spin site 94 has been flipped.
# Spin site 73:
#     Energy before flip is -2.315079371590645
#     Energy after flip is 2.315079371590645
#     Spin site 73 has not been flipped.
# Spin site 3:
#     Energy before flip is 0.7521154420585706
#     Energy after flip is -0.7521154420585706
#     Spin site 3 has been flipped.
# Spin site 84:
#     Energy before flip is 0.23761209960847796
#     Energy after flip is -0.23761209960847796
#     Spin site 84 has been flipped.
# Spin site 52:
#     Energy before flip is -0.07920336205747663
#     Energy after flip is 0.07920336205747663
#     Spin site 52 has not been flipped.
# Spin site 83:
#     Energy before flip is -1.2274006424895407
#     Energy after flip is 1.2274006424895407
#     Spin site 83 has not been flipped.
# Spin site 76:
#     Energy before flip is -1.904960978866745
#     Energy after flip is 1.904960978866745
#     Spin site 76 has not been flipped.
# Spin site 86:
#     Energy before flip is -0.019233865540888843
#     Energy after flip is 0.019233865540888843
#     Spin site 86 has not been flipped.
# Spin site 63:
#     Energy before flip is 0.9104019752813305
#     Energy after flip is -0.9104019752813305
#     Spin site 63 has been flipped.
# Spin site 98:
#     Energy before flip is 3.9915111855316923
#     Energy after flip is -3.9915111855316923
#     Spin site 98 has been flipped.
# Spin site 84:
#     Energy before flip is -0.23761209960847796
#     Energy after flip is 0.23761209960847796
#     Spin site 84 has not been flipped.
# Spin site 93:
#     Energy before flip is -0.6614464683234705
#     Energy after flip is 0.6614464683234705
#     Spin site 93 has not been flipped.
# Spin site 75:
#     Energy before flip is -0.7311821107336514
#     Energy after flip is 0.7311821107336514
#     Spin site 75 has not been flipped.
# Spin site 79:
#     Energy before flip is 2.048908710353724
#     Energy after flip is -2.048908710353724
#     Spin site 79 has been flipped.
# Spin site 99:
#     Energy before flip is -5.257346425165103
#     Energy after flip is 5.257346425165103
#     Spin site 99 has not been flipped.
# Spin site 26:
#     Energy before flip is -0.8129700467290837
#     Energy after flip is 0.8129700467290837
#     Spin site 26 has not been flipped.
# Spin site 95:
#     Energy before flip is -1.2789607153755287
#     Energy after flip is 1.2789607153755287
#     Spin site 95 has not been flipped.
# Spin site 8:
#     Energy before flip is 1.7104312528537853
#     Energy after flip is -1.7104312528537853
#     Spin site 8 has been flipped.
# Spin site 82:
#     Energy before flip is 0.4817229839445407
#     Energy after flip is -0.4817229839445407
#     Spin site 82 has been flipped.
# Spin site 74:
#     Energy before flip is -1.57897568370451
#     Energy after flip is 1.57897568370451
#     Spin site 74 has not been flipped.
# Spin site 24:
#     Energy before flip is 0.9018821794682204
#     Energy after flip is -0.9018821794682204
#     Spin site 24 has been flipped.
# Spin site 37:
#     Energy before flip is -0.38209058715989364
#     Energy after flip is 0.38209058715989364
#     Spin site 37 has not been flipped.
# Spin site 25:
#     Energy before flip is -1.9744334687298317
#     Energy after flip is 1.9744334687298317
#     Spin site 25 has not been flipped.
# Spin site 39:
#     Energy before flip is -0.5649593446821285
#     Energy after flip is 0.5649593446821285
#     Spin site 39 has not been flipped.
# Spin site 83:
#     Energy before flip is -0.07384674838772765
#     Energy after flip is 0.07384674838772765
#     Spin site 83 has not been flipped.
# Spin site 2:
#     Energy before flip is -2.1670049467744703
#     Energy after flip is 2.1670049467744703
#     Spin site 2 has not been flipped.
# Spin site 65:
#     Energy before flip is 0.05050335321760924
#     Energy after flip is -0.05050335321760924
#     Spin site 65 has been flipped.
# Spin site 25:
#     Energy before flip is -1.9744334687298317
#     Energy after flip is 1.9744334687298317
#     Spin site 25 has not been flipped.
# Spin site 19:
#     Energy before flip is -0.7354802201132203
#     Energy after flip is 0.7354802201132203
#     Spin site 19 has not been flipped.
# Spin site 60:
#     Energy before flip is 0.39934127471688824
#     Energy after flip is -0.39934127471688824
#     Spin site 60 has been flipped.
# Spin site 84:
#     Energy before flip is -0.23761209960847796
#     Energy after flip is 0.23761209960847796
#     Spin site 84 has not been flipped.
# Spin site 53:
#     Energy before flip is 0.9625772223984042
#     Energy after flip is -0.9625772223984042
#     Spin site 53 has been flipped.
# Spin site 35:
#     Energy before flip is -0.642365161239954
#     Energy after flip is 0.642365161239954
#     Spin site 35 has not been flipped.
# Spin site 9:
#     Energy before flip is -0.08103738023557128
#     Energy after flip is 0.08103738023557128
#     Spin site 9 has not been flipped.
# Spin site 76:
#     Energy before flip is -1.904960978866745
#     Energy after flip is 1.904960978866745
#     Spin site 76 has not been flipped.
# Spin site 37:
#     Energy before flip is -0.38209058715989364
#     Energy after flip is 0.38209058715989364
#     Spin site 37 has not been flipped.
# Spin site 8:
#     Energy before flip is -1.7104312528537853
#     Energy after flip is 1.7104312528537853
#     Spin site 8 has not been flipped.
# Spin site 42:
#     Energy before flip is 0.4265426099443184
#     Energy after flip is -0.4265426099443184
#     Spin site 42 has been flipped.
# Spin site 97:
#     Energy before flip is -1.1281432731054548
#     Energy after flip is 1.1281432731054548
#     Spin site 97 has not been flipped.
# Spin site 59:
#     Energy before flip is -2.0573188168581327
#     Energy after flip is 2.0573188168581327
#     Spin site 59 has not been flipped.
# Spin site 39:
#     Energy before flip is -0.5649593446821285
#     Energy after flip is 0.5649593446821285
#     Spin site 39 has not been flipped.
# Spin site 62:
#     Energy before flip is 1.1625025176161645
#     Energy after flip is -1.1625025176161645
#     Spin site 62 has been flipped.
# Spin site 94:
#     Energy before flip is -0.1627639628399985
#     Energy after flip is 0.1627639628399985
#     Spin site 94 has not been flipped.
# Spin site 32:
#     Energy before flip is -1.639736818348554
#     Energy after flip is 1.639736818348554
#     Spin site 32 has not been flipped.
# Spin site 71:
#     Energy before flip is 1.1308652610330985
#     Energy after flip is -1.1308652610330985
#     Spin site 71 has been flipped.
# Spin site 17:
#     Energy before flip is -1.0672630421936495
#     Energy after flip is 1.0672630421936495
#     Spin site 17 has not been flipped.
# Spin site 94:
#     Energy before flip is -0.1627639628399985
#     Energy after flip is 0.1627639628399985
#     Spin site 94 has not been flipped.
# Spin site 87:
#     Energy before flip is -1.1601909341679435
#     Energy after flip is 1.1601909341679435
#     Spin site 87 has not been flipped.
# Spin site 99:
#     Energy before flip is -5.257346425165103
#     Energy after flip is 5.257346425165103
#     Spin site 99 has not been flipped.
# Spin site 42:
#     Energy before flip is -0.4265426099443184
#     Energy after flip is 0.4265426099443184
#     Spin site 42 has not been flipped.
# Spin site 97:
#     Energy before flip is -1.1281432731054548
#     Energy after flip is 1.1281432731054548
#     Spin site 97 has not been flipped.
# Spin site 88:
#     Energy before flip is -3.032600310643518
#     Energy after flip is 3.032600310643518
#     Spin site 88 has not been flipped.
# Spin site 97:
#     Energy before flip is -1.1281432731054548
#     Energy after flip is 1.1281432731054548
#     Spin site 97 has not been flipped.
# Spin site 54:
#     Energy before flip is -1.1831663601325435
#     Energy after flip is 1.1831663601325435
#     Spin site 54 has not been flipped.
# Spin site 84:
#     Energy before flip is -0.23761209960847796
#     Energy after flip is 0.23761209960847796
#     Spin site 84 has not been flipped.
# Spin site 27:
#     Energy before flip is 0.0724672129524136
#     Energy after flip is -0.0724672129524136
#     Spin site 27 has been flipped.
# Spin site 31:
#     Energy before flip is -2.9098965967774557
#     Energy after flip is 2.9098965967774557
#     Spin site 31 has not been flipped.
# Spin site 5:
#     Energy before flip is -1.6352544019558
#     Energy after flip is 1.6352544019558
#     Spin site 5 has not been flipped.
# Spin site 8:
#     Energy before flip is -1.7104312528537853
#     Energy after flip is 1.7104312528537853
#     Spin site 8 has not been flipped.
# Spin site 92:
#     Energy before flip is -1.0373307136637258
#     Energy after flip is 1.0373307136637258
#     Spin site 92 has not been flipped.
# Spin site 10:
#     Energy before flip is 0.40756530509154226
#     Energy after flip is -0.40756530509154226
#     Spin site 10 has been flipped.
# Spin site 0:
#     Energy before flip is -4.288086695010205
#     Energy after flip is 4.288086695010205
#     Spin site 0 has not been flipped.
# Spin site 19:
#     Energy before flip is -0.7354802201132203
#     Energy after flip is 0.7354802201132203
#     Spin site 19 has not been flipped.
# Spin site 35:
#     Energy before flip is -0.642365161239954
#     Energy after flip is 0.642365161239954
#     Spin site 35 has not been flipped.
# Spin site 86:
#     Energy before flip is -0.019233865540888843
#     Energy after flip is 0.019233865540888843
#     Spin site 86 has not been flipped.
# Spin site 18:
#     Energy before flip is 0.5631015148641774
#     Energy after flip is -0.5631015148641774
#     Spin site 18 has been flipped.
# Spin site 11:
#     Energy before flip is -0.14295835077998087
#     Energy after flip is 0.14295835077998087
#     Spin site 11 has not been flipped.
# Spin site 31:
#     Energy before flip is -2.9098965967774557
#     Energy after flip is 2.9098965967774557
#     Spin site 31 has not been flipped.
# Spin site 84:
#     Energy before flip is -0.23761209960847796
#     Energy after flip is 0.23761209960847796
#     Spin site 84 has not been flipped.
# Spin site 40:
#     Energy before flip is -2.0752537691061748
#     Energy after flip is 2.0752537691061748
#     Spin site 40 has not been flipped.
# Spin site 50:
#     Energy before flip is 1.0373096181946568
#     Energy after flip is -1.0373096181946568
#     Spin site 50 has been flipped.
# Spin site 38:
#     Energy before flip is -0.921173479408916
#     Energy after flip is 0.921173479408916
#     Spin site 38 has not been flipped.
# Spin site 49:
#     Energy before flip is -0.8483981596012203
#     Energy after flip is 0.8483981596012203
#     Spin site 49 has not been flipped.
# Spin site 80:
#     Energy before flip is -0.3712630053844854
#     Energy after flip is 0.3712630053844854
#     Spin site 80 has not been flipped.
# Spin site 14:
#     Energy before flip is -0.1970084260479159
#     Energy after flip is 0.1970084260479159
#     Spin site 14 has not been flipped.
# Spin site 80:
#     Energy before flip is -0.3712630053844854
#     Energy after flip is 0.3712630053844854
#     Spin site 80 has not been flipped.
# Spin site 42:
#     Energy before flip is -0.4265426099443184
#     Energy after flip is 0.4265426099443184
#     Spin site 42 has not been flipped.
# Spin site 73:
#     Energy before flip is -2.315079371590645
#     Energy after flip is 2.315079371590645
#     Spin site 73 has not been flipped.
# Spin site 9:
#     Energy before flip is -0.8384509709103465
#     Energy after flip is 0.8384509709103465
#     Spin site 9 has not been flipped.
# Spin site 84:
#     Energy before flip is -0.23761209960847796
#     Energy after flip is 0.23761209960847796
#     Spin site 84 has not been flipped.
# Spin site 85:
#     Energy before flip is 0.3770752727093966
#     Energy after flip is -0.3770752727093966
#     Spin site 85 has been flipped.
# Spin site 29:
#     Energy before flip is -0.9414986726124444
#     Energy after flip is 0.9414986726124444
#     Spin site 29 has not been flipped.
# Spin site 20:
#     Energy before flip is -0.18374408252108831
#     Energy after flip is 0.18374408252108831
#     Spin site 20 has not been flipped.
# Spin site 80:
#     Energy before flip is -0.3712630053844854
#     Energy after flip is 0.3712630053844854
#     Spin site 80 has not been flipped.
# Spin site 11:
#     Energy before flip is -0.14295835077998087
#     Energy after flip is 0.14295835077998087
#     Spin site 11 has not been flipped.
# Spin site 29:
#     Energy before flip is -0.9414986726124444
#     Energy after flip is 0.9414986726124444
#     Spin site 29 has not been flipped.
# Spin site 91:
#     Energy before flip is -0.4924726577076908
#     Energy after flip is 0.4924726577076908
#     Spin site 91 has not been flipped.
# Spin site 42:
#     Energy before flip is -0.4265426099443184
#     Energy after flip is 0.4265426099443184
#     Spin site 42 has not been flipped.
# Spin site 73:
#     Energy before flip is -2.315079371590645
#     Energy after flip is 2.315079371590645
#     Spin site 73 has not been flipped.
# Spin site 26:
#     Energy before flip is -0.5294715968244268
#     Energy after flip is 0.5294715968244268
#     Spin site 26 has not been flipped.
# Spin site 50:
#     Energy before flip is -1.0373096181946568
#     Energy after flip is 1.0373096181946568
#     Spin site 50 has not been flipped.

# %%
active_dict_1 = {}
for key in spin_dict_1:
    active_dict_1[key] = spin_dict_1[key]
# print(active_dict)
while active_dict_1:
    t = monte_carlo(t, spin_dict_1, active_dict_1)
print("Twin 1 has reached absorbing state.")
# Out:
# s not been flipped.
# Spin site 84 has been removed from active list
# Spin site 63:
#     Energy before flip is 0.9104019752813305
#     Energy after flip is -0.9104019752813305
#     Spin site 63 has been flipped.
# Spin site 97:
#     Energy before flip is -1.1281432731054548
#     Energy after flip is 1.1281432731054548
#     Spin site 97 has not been flipped.
# Spin site 97 has been removed from active list
# Spin site 14:
#     Energy before flip is -0.1970084260479159
#     Energy after flip is 0.1970084260479159
#     Spin site 14 has not been flipped.
# Spin site 14 has been removed from active list
# Spin site 72:
#     Energy before flip is -1.3165434316270972
#     Energy after flip is 1.3165434316270972
#     Spin site 72 has not been flipped.
# Spin site 72 has been removed from active list
# Spin site 61:
#     Energy before flip is -0.9339778823864551
#     Energy after flip is 0.9339778823864551
#     Spin site 61 has not been flipped.
# Spin site 61 has been removed from active list
# Spin site 16:
#     Energy before flip is -0.3109450368651901
#     Energy after flip is 0.3109450368651901
#     Spin site 16 has not been flipped.
# Spin site 16 has been removed from active list
# Spin site 69:
#     Energy before flip is -1.3037229458017814
#     Energy after flip is 1.3037229458017814
#     Spin site 69 has not been flipped.
# Spin site 69 has been removed from active list
# Spin site 45:
#     Energy before flip is 0.7988416485076266
#     Energy after flip is -0.7988416485076266
#     Spin site 45 has been flipped.
# Spin site 49:
#     Energy before flip is -0.8483981596012203
#     Energy after flip is 0.8483981596012203
#     Spin site 49 has not been flipped.
# Spin site 49 has been removed from active list
# Spin site 85:
#     Energy before flip is -0.3770752727093966
#     Energy after flip is 0.3770752727093966
#     Spin site 85 has not been flipped.
# Spin site 85 has been removed from active list
# Spin site 64:
#     Energy before flip is -1.3965485154545512
#     Energy after flip is 1.3965485154545512
#     Spin site 64 has not been flipped.
# Spin site 64 has been removed from active list
# Spin site 95:
#     Energy before flip is -1.2789607153755287
#     Energy after flip is 1.2789607153755287
#     Spin site 95 has not been flipped.
# Spin site 95 has been removed from active list
# Spin site 86:
#     Energy before flip is 0.052638780700630376
#     Energy after flip is -0.052638780700630376
#     Spin site 86 has been flipped.
# Spin site 81:
#     Energy before flip is -0.07712057709237663
#     Energy after flip is 0.07712057709237663
#     Spin site 81 has not been flipped.
# Spin site 81 has been removed from active list
# Spin site 65:
#     Energy before flip is -1.519686861674046
#     Energy after flip is 1.519686861674046
#     Spin site 65 has not been flipped.
# Spin site 65 has been removed from active list
# Spin site 60:
#     Energy before flip is -0.39934127471688824
#     Energy after flip is 0.39934127471688824
#     Spin site 60 has not been flipped.
# Spin site 60 has been removed from active list
# Spin site 54:
#     Energy before flip is -1.1831663601325435
#     Energy after flip is 1.1831663601325435
#     Spin site 54 has not been flipped.
# Spin site 54 has been removed from active list
# Spin site 23:
#     Energy before flip is 1.2799029004371634
#     Energy after flip is -1.2799029004371634
#     Spin site 23 has been flipped.
# Spin site 70:
#     Energy before flip is -1.3501346591359074
#     Energy after flip is 1.3501346591359074
#     Spin site 70 has not been flipped.
# Spin site 70 has been removed from active list
# Spin site 62:
#     Energy before flip is -1.6593929457261596
#     Energy after flip is 1.6593929457261596
#     Spin site 62 has not been flipped.
# Spin site 62 has been removed from active list
# Spin site 13:
#     Energy before flip is -2.316466865859666
#     Energy after flip is 2.316466865859666
#     Spin site 13 has not been flipped.
# Spin site 13 has been removed from active list
# Spin site 59:
#     Energy before flip is -2.0573188168581327
#     Energy after flip is 2.0573188168581327
#     Spin site 59 has not been flipped.
# Spin site 59 has been removed from active list
# Spin site 27:
#     Energy before flip is -0.0724672129524136
#     Energy after flip is 0.0724672129524136
#     Spin site 27 has not been flipped.
# Spin site 27 has been removed from active list
# Spin site 29:
#     Energy before flip is -0.9414986726124444
#     Energy after flip is 0.9414986726124444
#     Spin site 29 has not been flipped.
# Spin site 29 has been removed from active list
# Spin site 5:
#     Energy before flip is -1.6352544019558
#     Energy after flip is 1.6352544019558
#     Spin site 5 has not been flipped.
# Spin site 5 has been removed from active list
# Spin site 66:
#     Energy before flip is 0.21083494411532766
#     Energy after flip is -0.21083494411532766
#     Spin site 66 has been flipped.
# Spin site 67:
#     Energy before flip is -2.4969826979514513
#     Energy after flip is 2.4969826979514513
#     Spin site 67 has not been flipped.
# Spin site 67 has been removed from active list
# Spin site 52:
#     Energy before flip is -0.9490384959518225
#     Energy after flip is 0.9490384959518225
#     Spin site 52 has not been flipped.
# Spin site 52 has been removed from active list
# Spin site 77:
#     Energy before flip is -1.451295470952048
#     Energy after flip is 1.451295470952048
#     Spin site 77 has not been flipped.
# Spin site 77 has been removed from active list
# Spin site 63:
#     Energy before flip is -0.9104019752813305
#     Energy after flip is 0.9104019752813305
#     Spin site 63 has not been flipped.
# Spin site 63 has been removed from active list
# Spin site 4:
#     Energy before flip is -1.0571786700653312
#     Energy after flip is 1.0571786700653312
#     Spin site 4 has not been flipped.
# Spin site 4 has been removed from active list
# Spin site 48:
#     Energy before flip is -1.8074375877140652
#     Energy after flip is 1.8074375877140652
#     Spin site 48 has not been flipped.
# Spin site 48 has been removed from active list
# Spin site 73:
#     Energy before flip is -2.315079371590645
#     Energy after flip is 2.315079371590645
#     Spin site 73 has not been flipped.
# Spin site 73 has been removed from active list
# Spin site 45:
#     Energy before flip is -0.7988416485076266
#     Energy after flip is 0.7988416485076266
#     Spin site 45 has not been flipped.
# Spin site 45 has been removed from active list
# Spin site 23:
#     Energy before flip is -1.2799029004371634
#     Energy after flip is 1.2799029004371634
#     Spin site 23 has not been flipped.
# Spin site 23 has been removed from active list
# Spin site 19:
#     Energy before flip is -2.4385390125314137
#     Energy after flip is 2.4385390125314137
#     Spin site 19 has not been flipped.
# Spin site 19 has been removed from active list
# Spin site 15:
#     Energy before flip is 0.9992483622837267
#     Energy after flip is -0.9992483622837267
#     Spin site 15 has been flipped.
# Spin site 6:
#     Energy before flip is -0.7923529346931857
#     Energy after flip is 0.7923529346931857
#     Spin site 6 has not been flipped.
# Spin site 6 has been removed from active list
# Spin site 32:
#     Energy before flip is -1.639736818348554
#     Energy after flip is 1.639736818348554
#     Spin site 32 has not been flipped.
# Spin site 32 has been removed from active list
# Spin site 56:
#     Energy before flip is -1.0023452121119851
#     Energy after flip is 1.0023452121119851
#     Spin site 56 has not been flipped.
# Spin site 56 has been removed from active list
# Spin site 31:
#     Energy before flip is -2.9098965967774557
#     Energy after flip is 2.9098965967774557
#     Spin site 31 has not been flipped.
# Spin site 31 has been removed from active list
# Spin site 15:
#     Energy before flip is -0.9992483622837267
#     Energy after flip is 0.9992483622837267
#     Spin site 15 has not been flipped.
# Spin site 15 has been removed from active list
# Spin site 88:
#     Energy before flip is -3.032600310643518
#     Energy after flip is 3.032600310643518
#     Spin site 88 has not been flipped.
# Spin site 88 has been removed from active list
# Spin site 38:
#     Energy before flip is -0.921173479408916
#     Energy after flip is 0.921173479408916
#     Spin site 38 has not been flipped.
# Spin site 38 has been removed from active list
# Spin site 47:
#     Energy before flip is -1.6831971237144894
#     Energy after flip is 1.6831971237144894
#     Spin site 47 has not been flipped.
# Spin site 47 has been removed from active list
# Spin site 65:
#     Energy before flip is 0.05050335321760924
#     Energy after flip is -0.05050335321760924
#     Spin site 65 has been flipped.
# Spin site 86:
#     Energy before flip is -0.052638780700630376
#     Energy after flip is 0.052638780700630376
#     Spin site 86 has not been flipped.
# Spin site 86 has been removed from active list
# Spin site 7:
#     Energy before flip is -1.6523684658516626
#     Energy after flip is 1.6523684658516626
#     Spin site 7 has not been flipped.
# Spin site 7 has been removed from active list
# Spin site 58:
#     Energy before flip is -0.9669906273510258
#     Energy after flip is 0.9669906273510258
#     Spin site 58 has not been flipped.
# Spin site 58 has been removed from active list
# Spin site 17:
#     Energy before flip is -0.49040727950381097
#     Energy after flip is 0.49040727950381097
#     Spin site 17 has not been flipped.
# Spin site 17 has been removed from active list
# Spin site 87:
#     Energy before flip is -1.1935958493276848
#     Energy after flip is 1.1935958493276848
#     Spin site 87 has not been flipped.
# Spin site 87 has been removed from active list
# Spin site 33:
#     Energy before flip is 0.8296072916473295
#     Energy after flip is -0.8296072916473295
#     Spin site 33 has been flipped.
# Spin site 82:
#     Energy before flip is -0.4817229839445407
#     Energy after flip is 0.4817229839445407
#     Spin site 82 has not been flipped.
# Spin site 82 has been removed from active list
# Spin site 16:
#     Energy before flip is -1.2467252848322705
#     Energy after flip is 1.2467252848322705
#     Spin site 16 has not been flipped.
# Spin site 16 has been removed from active list
# Spin site 93:
#     Energy before flip is -0.6614464683234705
#     Energy after flip is 0.6614464683234705
#     Spin site 93 has not been flipped.
# Spin site 93 has been removed from active list
# Spin site 98:
#     Energy before flip is -3.9915111855316923
#     Energy after flip is 3.9915111855316923
#     Spin site 98 has not been flipped.
# Spin site 98 has been removed from active list
# Spin site 46:
#     Energy before flip is -1.458799777715225
#     Energy after flip is 1.458799777715225
#     Spin site 46 has not been flipped.
# Spin site 46 has been removed from active list
# Spin site 89:
#     Energy before flip is -3.1310490411225156
#     Energy after flip is 3.1310490411225156
#     Spin site 89 has not been flipped.
# Spin site 89 has been removed from active list
# Spin site 12:
#     Energy before flip is -1.7022000425373898
#     Energy after flip is 1.7022000425373898
#     Spin site 12 has not been flipped.
# Spin site 12 has been removed from active list
# Spin site 21:
#     Energy before flip is 1.2606419393179515
#     Energy after flip is -1.2606419393179515
#     Spin site 21 has been flipped.
# Spin site 34:
#     Energy before flip is 0.06439241142861027
#     Energy after flip is -0.06439241142861027
#     Spin site 34 has been flipped.
# Spin site 28:
#     Energy before flip is -1.410298410415209
#     Energy after flip is 1.410298410415209
#     Spin site 28 has not been flipped.
# Spin site 28 has been removed from active list
# Spin site 78:
#     Energy before flip is -1.0661388875678197
#     Energy after flip is 1.0661388875678197
#     Spin site 78 has not been flipped.
# Spin site 78 has been removed from active list
# Spin site 33:
#     Energy before flip is -1.112063613091716
#     Energy after flip is 1.112063613091716
#     Spin site 33 has not been flipped.
# Spin site 33 has been removed from active list
# Spin site 3:
#     Energy before flip is -0.7521154420585706
#     Energy after flip is 0.7521154420585706
#     Spin site 3 has not been flipped.
# Spin site 3 has been removed from active list
# Spin site 22:
#     Energy before flip is -0.73594883846903
#     Energy after flip is 0.73594883846903
#     Spin site 22 has not been flipped.
# Spin site 22 has been removed from active list
# Spin site 14:
#     Energy before flip is -1.2597249026482888
#     Energy after flip is 1.2597249026482888
#     Spin site 14 has not been flipped.
# Spin site 14 has been removed from active list
# Spin site 74:
#     Energy before flip is -1.57897568370451
#     Energy after flip is 1.57897568370451
#     Spin site 74 has not been flipped.
# Spin site 74 has been removed from active list
# Spin site 66:
#     Energy before flip is -1.781025159006983
#     Energy after flip is 1.781025159006983
#     Spin site 66 has not been flipped.
# Spin site 66 has been removed from active list
# Spin site 44:
#     Energy before flip is -0.8337426936586398
#     Energy after flip is 0.8337426936586398
#     Spin site 44 has not been flipped.
# Spin site 44 has been removed from active list
# Spin site 2:
#     Energy before flip is -2.1670049467744703
#     Energy after flip is 2.1670049467744703
#     Spin site 2 has not been flipped.
# Spin site 2 has been removed from active list
# Spin site 85:
#     Energy before flip is -0.44894791895091585
#     Energy after flip is 0.44894791895091585
#     Spin site 85 has not been flipped.
# Spin site 85 has been removed from active list
# Spin site 79:
#     Energy before flip is -2.048908710353724
#     Energy after flip is 2.048908710353724
#     Spin site 79 has not been flipped.
# Spin site 79 has been removed from active list
# Spin site 68:
#     Energy before flip is -1.9127105166656087
#     Energy after flip is 1.9127105166656087
#     Spin site 68 has not been flipped.
# Spin site 68 has been removed from active list
# Spin site 32:
#     Energy before flip is -3.5814077230875996
#     Energy after flip is 3.5814077230875996
#     Spin site 32 has not been flipped.
# Spin site 32 has been removed from active list
# Spin site 24:
#     Energy before flip is -1.7045431144379326
#     Energy after flip is 1.7045431144379326
#     Spin site 24 has not been flipped.
# Spin site 24 has been removed from active list
# Spin site 35:
#     Energy before flip is -0.4886936626527879
#     Energy after flip is 0.4886936626527879
#     Spin site 35 has not been flipped.
# Spin site 35 has been removed from active list
# Spin site 65:
#     Energy before flip is -0.05050335321760924
#     Energy after flip is 0.05050335321760924
#     Spin site 65 has not been flipped.
# Spin site 65 has been removed from active list
# Spin site 64:
#     Energy before flip is 0.07263499300188558
#     Energy after flip is -0.07263499300188558
#     Spin site 64 has been flipped.
# Spin site 41:
#     Energy before flip is -0.775700420483278
#     Energy after flip is 0.775700420483278
#     Spin site 41 has not been flipped.
# Spin site 41 has been removed from active list
# Spin site 57:
#     Energy before flip is 1.853020113876529
#     Energy after flip is -1.853020113876529
#     Spin site 57 has been flipped.
# Spin site 40:
#     Energy before flip is -2.0752537691061748
#     Energy after flip is 2.0752537691061748
#     Spin site 40 has not been flipped.
# Spin site 40 has been removed from active list
# Spin site 34:
#     Energy before flip is -0.06439241142861027
#     Energy after flip is 0.06439241142861027
#     Spin site 34 has not been flipped.
# Spin site 34 has been removed from active list
# Spin site 64:
#     Energy before flip is -0.07263499300188558
#     Energy after flip is 0.07263499300188558
#     Spin site 64 has not been flipped.
# Spin site 64 has been removed from active list
# Spin site 71:
#     Energy before flip is -1.1308652610330985
#     Energy after flip is 1.1308652610330985
#     Spin site 71 has not been flipped.
# Spin site 71 has been removed from active list
# Spin site 96:
#     Energy before flip is -0.5701364358378891
#     Energy after flip is 0.5701364358378891
#     Spin site 96 has not been flipped.
# Spin site 96 has been removed from active list
# Spin site 65:
#     Energy before flip is -1.519686861674046
#     Energy after flip is 1.519686861674046
#     Spin site 65 has not been flipped.
# Spin site 65 has been removed from active list
# Spin site 56:
#     Energy before flip is -4.28035130885402
#     Energy after flip is 4.28035130885402
#     Spin site 56 has not been flipped.
# Spin site 56 has been removed from active list
# Spin site 58:
#     Energy before flip is -1.395024758362049
#     Energy after flip is 1.395024758362049
#     Spin site 58 has not been flipped.
# Spin site 58 has been removed from active list
# Spin site 30:
#     Energy before flip is -0.0447410261613565
#     Energy after flip is 0.0447410261613565
#     Spin site 30 has not been flipped.
# Spin site 30 has been removed from active list
# Spin site 36:
#     Energy before flip is 0.5397200662365547
#     Energy after flip is -0.5397200662365547
#     Spin site 36 has been flipped.
# Spin site 25:
#     Energy before flip is -1.9744334687298317
#     Energy after flip is 1.9744334687298317
#     Spin site 25 has not been flipped.
# Spin site 25 has been removed from active list
# Spin site 76:
#     Energy before flip is -1.904960978866745
#     Energy after flip is 1.904960978866745
#     Spin site 76 has not been flipped.
# Spin site 76 has been removed from active list
# Spin site 80:
#     Energy before flip is -0.3712630053844854
#     Energy after flip is 0.3712630053844854
#     Spin site 80 has not been flipped.
# Spin site 80 has been removed from active list
# Spin site 55:
#     Energy before flip is -3.296854965164315
#     Energy after flip is 3.296854965164315
#     Spin site 55 has not been flipped.
# Spin site 55 has been removed from active list
# Spin site 63:
#     Energy before flip is 0.4135115471713352
#     Energy after flip is -0.4135115471713352
#     Spin site 63 has been flipped.
# Spin site 64:
#     Energy before flip is -1.3965485154545512
#     Energy after flip is 1.3965485154545512
#     Spin site 64 has not been flipped.
# Spin site 64 has been removed from active list
# Spin site 62:
#     Energy before flip is -1.1625025176161645
#     Energy after flip is 1.1625025176161645
#     Spin site 62 has not been flipped.
# Spin site 62 has been removed from active list
# Spin site 37:
#     Energy before flip is -2.5925895435257447
#     Energy after flip is 2.5925895435257447
#     Spin site 37 has not been flipped.
# Spin site 37 has been removed from active list
# Spin site 63:
#     Energy before flip is -0.4135115471713352
#     Energy after flip is 0.4135115471713352
#     Spin site 63 has not been flipped.
# Spin site 63 has been removed from active list
# Spin site 20:
#     Energy before flip is -2.990275150123546
#     Energy after flip is 2.990275150123546
#     Spin site 20 has not been flipped.
# Spin site 20 has been removed from active list
# Spin site 57:
#     Energy before flip is -1.853020113876529
#     Energy after flip is 1.853020113876529
#     Spin site 57 has not been flipped.
# Spin site 57 has been removed from active list
# Spin site 21:
#     Energy before flip is -1.2606419393179515
#     Energy after flip is 1.2606419393179515
#     Spin site 21 has not been flipped.
# Spin site 21 has been removed from active list
# Spin site 35:
#     Energy before flip is 0.642365161239954
#     Energy after flip is -0.642365161239954
#     Spin site 35 has been flipped.
# Spin site 75:
#     Energy before flip is -0.7311821107336514
#     Energy after flip is 0.7311821107336514
#     Spin site 75 has not been flipped.
# Spin site 75 has been removed from active list
# Spin site 36:
#     Energy before flip is -1.6707788901292966
#     Energy after flip is 1.6707788901292966
#     Spin site 36 has not been flipped.
# Spin site 36 has been removed from active list
# Spin site 94:
#     Energy before flip is -0.1627639628399985
#     Energy after flip is 0.1627639628399985
#     Spin site 94 has not been flipped.
# Spin site 94 has been removed from active list
# Spin site 34:
#     Energy before flip is -0.21806391001577644
#     Energy after flip is 0.21806391001577644
#     Spin site 34 has not been flipped.
# Spin site 34 has been removed from active list
# Spin site 35:
#     Energy before flip is -0.642365161239954
#     Energy after flip is 0.642365161239954
#     Spin site 35 has not been flipped.
# Spin site 35 has been removed from active list
# Twin 1 has reached absorbing state.

# %%
t = 0
while t < switch_time: # t measured in sweeps - one sweep = N spin-flip attempts
    t = glauber(t, spin_dict_2)
# Out:
# Spin site 44:
#     Energy before flip is 0.45957275240027945
#     Energy after flip is -0.45957275240027945
#     Spin site 44 has been flipped.
# Spin site 14:
#     Energy before flip is -0.1970084260479159
#     Energy after flip is 0.1970084260479159
#     Spin site 14 has not been flipped.
# Spin site 89:
#     Energy before flip is -3.1310490411225156
#     Energy after flip is 3.1310490411225156
#     Spin site 89 has not been flipped.
# Spin site 45:
#     Energy before flip is -0.7988416485076266
#     Energy after flip is 0.7988416485076266
#     Spin site 45 has not been flipped.
# Spin site 79:
#     Energy before flip is 2.048908710353724
#     Energy after flip is -2.048908710353724
#     Spin site 79 has been flipped.
# Spin site 3:
#     Energy before flip is 0.7521154420585706
#     Energy after flip is -0.7521154420585706
#     Spin site 3 has been flipped.
# Spin site 56:
#     Energy before flip is 1.0023452121119851
#     Energy after flip is -1.0023452121119851
#     Spin site 56 has been flipped.
# Spin site 53:
#     Energy before flip is 0.9625772223984042
#     Energy after flip is -0.9625772223984042
#     Spin site 53 has been flipped.
# Spin site 70:
#     Energy before flip is -0.4339954919170303
#     Energy after flip is 0.4339954919170303
#     Spin site 70 has not been flipped.
# Spin site 75:
#     Energy before flip is -0.7311821107336514
#     Energy after flip is 0.7311821107336514
#     Spin site 75 has not been flipped.
# Spin site 42:
#     Energy before flip is 0.4265426099443184
#     Energy after flip is -0.4265426099443184
#     Spin site 42 has been flipped.
# Spin site 13:
#     Energy before flip is -2.316466865859666
#     Energy after flip is 2.316466865859666
#     Spin site 13 has not been flipped.
# Spin site 40:
#     Energy before flip is -2.0752537691061748
#     Energy after flip is 2.0752537691061748
#     Spin site 40 has not been flipped.
# Spin site 80:
#     Energy before flip is -0.3712630053844854
#     Energy after flip is 0.3712630053844854
#     Spin site 80 has not been flipped.
# Spin site 94:
#     Energy before flip is 0.1627639628399985
#     Energy after flip is -0.1627639628399985
#     Spin site 94 has been flipped.
# Spin site 51:
#     Energy before flip is 1.1056468458254207
#     Energy after flip is -1.1056468458254207
#     Spin site 51 has been flipped.
# Spin site 80:
#     Energy before flip is -0.3712630053844854
#     Energy after flip is 0.3712630053844854
#     Spin site 80 has not been flipped.
# Spin site 37:
#     Energy before flip is -0.38209058715989364
#     Energy after flip is 0.38209058715989364
#     Spin site 37 has not been flipped.
# Spin site 58:
#     Energy before flip is -0.9669906273510258
#     Energy after flip is 0.9669906273510258
#     Spin site 58 has not been flipped.
# Spin site 63:
#     Energy before flip is 0.9104019752813305
#     Energy after flip is -0.9104019752813305
#     Spin site 63 has been flipped.
# Spin site 48:
#     Energy before flip is 1.8074375877140652
#     Energy after flip is -1.8074375877140652
#     Spin site 48 has been flipped.
# Spin site 25:
#     Energy before flip is 0.6319918251763212
#     Energy after flip is -0.6319918251763212
#     Spin site 25 has been flipped.
# Spin site 65:
#     Energy before flip is 0.05050335321760924
#     Energy after flip is -0.05050335321760924
#     Spin site 65 has been flipped.
# Spin site 10:
#     Energy before flip is 0.40756530509154226
#     Energy after flip is -0.40756530509154226
#     Spin site 10 has been flipped.
# Spin site 55:
#     Energy before flip is -3.296854965164315
#     Energy after flip is 3.296854965164315
#     Spin site 55 has not been flipped.
# Spin site 47:
#     Energy before flip is 0.9300345807596269
#     Energy after flip is -0.9300345807596269
#     Spin site 47 has been flipped.
# Spin site 15:
#     Energy before flip is 0.9992483622837267
#     Energy after flip is -0.9992483622837267
#     Spin site 15 has been flipped.
# Spin site 40:
#     Energy before flip is -2.0752537691061748
#     Energy after flip is 2.0752537691061748
#     Spin site 40 has not been flipped.
# Spin site 78:
#     Energy before flip is -1.0661388875678197
#     Energy after flip is 1.0661388875678197
#     Spin site 78 has not been flipped.
# Spin site 90:
#     Energy before flip is -1.4608330404725036
#     Energy after flip is 1.4608330404725036
#     Spin site 90 has not been flipped.
# Spin site 59:
#     Energy before flip is -0.30469656885494223
#     Energy after flip is 0.30469656885494223
#     Spin site 59 has not been flipped.
# Spin site 56:
#     Energy before flip is -1.0023452121119851
#     Energy after flip is 1.0023452121119851
#     Spin site 56 has not been flipped.
# Spin site 94:
#     Energy before flip is -0.1627639628399985
#     Energy after flip is 0.1627639628399985
#     Spin site 94 has not been flipped.
# Spin site 86:
#     Energy before flip is -0.019233865540888843
#     Energy after flip is 0.019233865540888843
#     Spin site 86 has not been flipped.
# Spin site 42:
#     Energy before flip is -0.4265426099443184
#     Energy after flip is 0.4265426099443184
#     Spin site 42 has not been flipped.
# Spin site 94:
#     Energy before flip is -0.1627639628399985
#     Energy after flip is 0.1627639628399985
#     Spin site 94 has not been flipped.
# Spin site 22:
#     Energy before flip is 0.73594883846903
#     Energy after flip is -0.73594883846903
#     Spin site 22 has been flipped.
# Spin site 11:
#     Energy before flip is -0.14295835077998087
#     Energy after flip is 0.14295835077998087
#     Spin site 11 has not been flipped.
# Spin site 26:
#     Energy before flip is 0.5294715968244268
#     Energy after flip is -0.5294715968244268
#     Spin site 26 has been flipped.
# Spin site 3:
#     Energy before flip is -0.7521154420585706
#     Energy after flip is 0.7521154420585706
#     Spin site 3 has not been flipped.
# Spin site 50:
#     Energy before flip is -2.2022259314654837
#     Energy after flip is 2.2022259314654837
#     Spin site 50 has not been flipped.
# Spin site 68:
#     Energy before flip is 1.0893947761149834
#     Energy after flip is -1.0893947761149834
#     Spin site 68 has been flipped.
# Spin site 87:
#     Energy before flip is -1.1601909341679435
#     Energy after flip is 1.1601909341679435
#     Spin site 87 has not been flipped.
# Spin site 45:
#     Energy before flip is -0.7988416485076266
#     Energy after flip is 0.7988416485076266
#     Spin site 45 has not been flipped.
# Spin site 77:
#     Energy before flip is -1.451295470952048
#     Energy after flip is 1.451295470952048
#     Spin site 77 has not been flipped.
# Spin site 12:
#     Energy before flip is -1.7022000425373898
#     Energy after flip is 1.7022000425373898
#     Spin site 12 has not been flipped.
# Spin site 0:
#     Energy before flip is -4.288086695010205
#     Energy after flip is 4.288086695010205
#     Spin site 0 has not been flipped.
# Spin site 47:
#     Energy before flip is -0.9300345807596269
#     Energy after flip is 0.9300345807596269
#     Spin site 47 has not been flipped.
# Spin site 83:
#     Energy before flip is 0.07384674838772765
#     Energy after flip is -0.07384674838772765
#     Spin site 83 has been flipped.
# Spin site 76:
#     Energy before flip is -1.904960978866745
#     Energy after flip is 1.904960978866745
#     Spin site 76 has not been flipped.
# Spin site 22:
#     Energy before flip is -0.73594883846903
#     Energy after flip is 0.73594883846903
#     Spin site 22 has not been flipped.
# Spin site 40:
#     Energy before flip is -2.0752537691061748
#     Energy after flip is 2.0752537691061748
#     Spin site 40 has not been flipped.
# Spin site 58:
#     Energy before flip is -0.9669906273510258
#     Energy after flip is 0.9669906273510258
#     Spin site 58 has not been flipped.
# Spin site 69:
#     Energy before flip is -0.48040720525115627
#     Energy after flip is 0.48040720525115627
#     Spin site 69 has not been flipped.
# Spin site 87:
#     Energy before flip is -1.1601909341679435
#     Energy after flip is 1.1601909341679435
#     Spin site 87 has not been flipped.
# Spin site 59:
#     Energy before flip is -0.30469656885494223
#     Energy after flip is 0.30469656885494223
#     Spin site 59 has not been flipped.
# Spin site 26:
#     Energy before flip is -0.5294715968244268
#     Energy after flip is 0.5294715968244268
#     Spin site 26 has not been flipped.
# Spin site 26:
#     Energy before flip is -0.5294715968244268
#     Energy after flip is 0.5294715968244268
#     Spin site 26 has not been flipped.
# Spin site 15:
#     Energy before flip is -0.9992483622837267
#     Energy after flip is 0.9992483622837267
#     Spin site 15 has not been flipped.
# Spin site 59:
#     Energy before flip is -0.30469656885494223
#     Energy after flip is 0.30469656885494223
#     Spin site 59 has not been flipped.
# Spin site 73:
#     Energy before flip is -2.315079371590645
#     Energy after flip is 2.315079371590645
#     Spin site 73 has not been flipped.
# Spin site 29:
#     Energy before flip is -0.9414986726124444
#     Energy after flip is 0.9414986726124444
#     Spin site 29 has not been flipped.
# Spin site 7:
#     Energy before flip is 0.8490056887099904
#     Energy after flip is -0.8490056887099904
#     Spin site 7 has been flipped.
# Spin site 59:
#     Energy before flip is -0.30469656885494223
#     Energy after flip is 0.30469656885494223
#     Spin site 59 has not been flipped.
# Spin site 83:
#     Energy before flip is -0.07384674838772765
#     Energy after flip is 0.07384674838772765
#     Spin site 83 has not been flipped.
# Spin site 8:
#     Energy before flip is -0.7909429017078676
#     Energy after flip is 0.7909429017078676
#     Spin site 8 has not been flipped.
# Spin site 97:
#     Energy before flip is 1.1281432731054548
#     Energy after flip is -1.1281432731054548
#     Spin site 97 has been flipped.
# Spin site 96:
#     Energy before flip is 1.5244520574766587
#     Energy after flip is -1.5244520574766587
#     Spin site 96 has been flipped.
# Spin site 94:
#     Energy before flip is -0.1627639628399985
#     Energy after flip is 0.1627639628399985
#     Spin site 94 has not been flipped.
# Spin site 73:
#     Energy before flip is -2.315079371590645
#     Energy after flip is 2.315079371590645
#     Spin site 73 has not been flipped.
# Spin site 73:
#     Energy before flip is -2.315079371590645
#     Energy after flip is 2.315079371590645
#     Spin site 73 has not been flipped.
# Spin site 43:
#     Energy before flip is -0.40788505732200325
#     Energy after flip is 0.40788505732200325
#     Spin site 43 has not been flipped.
# Spin site 85:
#     Energy before flip is -0.44894791895091585
#     Energy after flip is 0.44894791895091585
#     Spin site 85 has not been flipped.
# Spin site 71:
#     Energy before flip is 1.1308652610330985
#     Energy after flip is -1.1308652610330985
#     Spin site 71 has been flipped.
# Spin site 79:
#     Energy before flip is -2.048908710353724
#     Energy after flip is 2.048908710353724
#     Spin site 79 has not been flipped.
# Spin site 70:
#     Energy before flip is -1.3501346591359074
#     Energy after flip is 1.3501346591359074
#     Spin site 70 has not been flipped.
# Spin site 19:
#     Energy before flip is 0.7354802201132203
#     Energy after flip is -0.7354802201132203
#     Spin site 19 has been flipped.
# Spin site 92:
#     Energy before flip is -1.0373307136637258
#     Energy after flip is 1.0373307136637258
#     Spin site 92 has not been flipped.
# Spin site 57:
#     Energy before flip is 1.853020113876529
#     Energy after flip is -1.853020113876529
#     Spin site 57 has been flipped.
# Spin site 64:
#     Energy before flip is 0.07263499300188558
#     Energy after flip is -0.07263499300188558
#     Spin site 64 has been flipped.
# Spin site 19:
#     Energy before flip is -0.7354802201132203
#     Energy after flip is 0.7354802201132203
#     Spin site 19 has not been flipped.
# Spin site 65:
#     Energy before flip is -1.519686861674046
#     Energy after flip is 1.519686861674046
#     Spin site 65 has not been flipped.
# Spin site 65:
#     Energy before flip is -1.519686861674046
#     Energy after flip is 1.519686861674046
#     Spin site 65 has not been flipped.
# Spin site 63:
#     Energy before flip is 0.4135115471713352
#     Energy after flip is -0.4135115471713352
#     Spin site 63 has been flipped.
# Spin site 66:
#     Energy before flip is -1.781025159006983
#     Energy after flip is 1.781025159006983
#     Spin site 66 has not been flipped.
# Spin site 48:
#     Energy before flip is -1.0542750447592026
#     Energy after flip is 1.0542750447592026
#     Spin site 48 has not been flipped.
# Spin site 18:
#     Energy before flip is 0.5631015148641774
#     Energy after flip is -0.5631015148641774
#     Spin site 18 has been flipped.
# Spin site 75:
#     Energy before flip is -0.7311821107336514
#     Energy after flip is 0.7311821107336514
#     Spin site 75 has not been flipped.
# Spin site 94:
#     Energy before flip is -0.1627639628399985
#     Energy after flip is 0.1627639628399985
#     Spin site 94 has not been flipped.
# Spin site 47:
#     Energy before flip is -0.9300345807596269
#     Energy after flip is 0.9300345807596269
#     Spin site 47 has not been flipped.
# Spin site 37:
#     Energy before flip is -0.38209058715989364
#     Energy after flip is 0.38209058715989364
#     Spin site 37 has not been flipped.
# Spin site 3:
#     Energy before flip is -0.7521154420585706
#     Energy after flip is 0.7521154420585706
#     Spin site 3 has not been flipped.
# Spin site 94:
#     Energy before flip is -0.1627639628399985
#     Energy after flip is 0.1627639628399985
#     Spin site 94 has not been flipped.
# Spin site 99:
#     Energy before flip is -0.48492622195139745
#     Energy after flip is 0.48492622195139745
#     Spin site 99 has not been flipped.
# Spin site 80:
#     Energy before flip is -0.3712630053844854
#     Energy after flip is 0.3712630053844854
#     Spin site 80 has not been flipped.
# Spin site 9:
#     Energy before flip is 0.08103738023557128
#     Energy after flip is -0.08103738023557128
#     Spin site 9 has been flipped.
# Spin site 82:
#     Energy before flip is 1.6352768780463538
#     Energy after flip is -1.6352768780463538
#     Spin site 82 has been flipped.
# Spin site 70:
#     Energy before flip is -1.3501346591359074
#     Energy after flip is 1.3501346591359074
#     Spin site 70 has not been flipped.
# Spin site 83:
#     Energy before flip is -1.2274006424895407
#     Energy after flip is 1.2274006424895407
#     Spin site 83 has not been flipped.
# Spin site 97:
#     Energy before flip is -2.0824588947442244
#     Energy after flip is 2.0824588947442244
#     Spin site 97 has not been flipped.

# %%
active_dict_2 = {}
for key in spin_dict_2:
    active_dict_2[key] = spin_dict_1[key]
# print(active_dict)
while active_dict_2:
    t = monte_carlo(t, spin_dict_2, active_dict_2)
print("Twin 2 has reached absorbing state.")
# Out:
# :
#     Energy before flip is -1.0542750447592026
#     Energy after flip is 1.0542750447592026
#     Spin site 48 has not been flipped.
# Spin site 48 has been removed from active list
# Spin site 28:
#     Energy before flip is -0.981865534605725
#     Energy after flip is 0.981865534605725
#     Spin site 28 has not been flipped.
# Spin site 28 has been removed from active list
# Spin site 2:
#     Energy before flip is -2.1670049467744703
#     Energy after flip is 2.1670049467744703
#     Spin site 2 has not been flipped.
# Spin site 2 has been removed from active list
# Spin site 16:
#     Energy before flip is -1.2467252848322705
#     Energy after flip is 1.2467252848322705
#     Spin site 16 has not been flipped.
# Spin site 16 has been removed from active list
# Spin site 52:
#     Energy before flip is 0.07920336205747663
#     Energy after flip is -0.07920336205747663
#     Spin site 52 has been flipped.
# Spin site 35:
#     Energy before flip is -0.642365161239954
#     Energy after flip is 0.642365161239954
#     Spin site 35 has not been flipped.
# Spin site 35 has been removed from active list
# Spin site 23:
#     Energy before flip is -1.2799029004371634
#     Energy after flip is 1.2799029004371634
#     Spin site 23 has not been flipped.
# Spin site 23 has been removed from active list
# Spin site 85:
#     Energy before flip is -0.44894791895091585
#     Energy after flip is 0.44894791895091585
#     Spin site 85 has not been flipped.
# Spin site 85 has been removed from active list
# Spin site 36:
#     Energy before flip is 0.5397200662365547
#     Energy after flip is -0.5397200662365547
#     Spin site 36 has been flipped.
# Spin site 80:
#     Energy before flip is -0.3712630053844854
#     Energy after flip is 0.3712630053844854
#     Spin site 80 has not been flipped.
# Spin site 80 has been removed from active list
# Spin site 72:
#     Energy before flip is -1.3165434316270972
#     Energy after flip is 1.3165434316270972
#     Spin site 72 has not been flipped.
# Spin site 72 has been removed from active list
# Spin site 42:
#     Energy before flip is -0.4265426099443184
#     Energy after flip is 0.4265426099443184
#     Spin site 42 has not been flipped.
# Spin site 42 has been removed from active list
# Spin site 54:
#     Energy before flip is -1.1831663601325435
#     Energy after flip is 1.1831663601325435
#     Spin site 54 has not been flipped.
# Spin site 54 has been removed from active list
# Spin site 56:
#     Energy before flip is -4.28035130885402
#     Energy after flip is 4.28035130885402
#     Spin site 56 has not been flipped.
# Spin site 56 has been removed from active list
# Spin site 4:
#     Energy before flip is -1.0571786700653312
#     Energy after flip is 1.0571786700653312
#     Spin site 4 has not been flipped.
# Spin site 4 has been removed from active list
# Spin site 97:
#     Energy before flip is -2.0824588947442244
#     Energy after flip is 2.0824588947442244
#     Spin site 97 has not been flipped.
# Spin site 97 has been removed from active list
# Spin site 47:
#     Energy before flip is -0.9300345807596269
#     Energy after flip is 0.9300345807596269
#     Spin site 47 has not been flipped.
# Spin site 47 has been removed from active list
# Spin site 5:
#     Energy before flip is -1.6352544019558
#     Energy after flip is 1.6352544019558
#     Spin site 5 has not been flipped.
# Spin site 5 has been removed from active list
# Spin site 27:
#     Energy before flip is 0.3559656628570705
#     Energy after flip is -0.3559656628570705
#     Spin site 27 has been flipped.
# Spin site 74:
#     Energy before flip is -1.57897568370451
#     Energy after flip is 1.57897568370451
#     Spin site 74 has not been flipped.
# Spin site 74 has been removed from active list
# Spin site 71:
#     Energy before flip is -1.1308652610330985
#     Energy after flip is 1.1308652610330985
#     Spin site 71 has not been flipped.
# Spin site 71 has been removed from active list
# Spin site 79:
#     Energy before flip is -2.048908710353724
#     Energy after flip is 2.048908710353724
#     Spin site 79 has not been flipped.
# Spin site 79 has been removed from active list
# Spin site 14:
#     Energy before flip is -1.2597249026482888
#     Energy after flip is 1.2597249026482888
#     Spin site 14 has not been flipped.
# Spin site 14 has been removed from active list
# Spin site 12:
#     Energy before flip is -1.7022000425373898
#     Energy after flip is 1.7022000425373898
#     Spin site 12 has not been flipped.
# Spin site 12 has been removed from active list
# Spin site 18:
#     Energy before flip is -0.5631015148641774
#     Energy after flip is 0.5631015148641774
#     Spin site 18 has not been flipped.
# Spin site 18 has been removed from active list
# Spin site 88:
#     Energy before flip is -3.032600310643518
#     Energy after flip is 3.032600310643518
#     Spin site 88 has not been flipped.
# Spin site 88 has been removed from active list
# Spin site 64:
#     Energy before flip is -1.3965485154545512
#     Energy after flip is 1.3965485154545512
#     Spin site 64 has not been flipped.
# Spin site 64 has been removed from active list
# Spin site 29:
#     Energy before flip is -0.9414986726124444
#     Energy after flip is 0.9414986726124444
#     Spin site 29 has not been flipped.
# Spin site 29 has been removed from active list
# Spin site 7:
#     Energy before flip is -0.8490056887099904
#     Energy after flip is 0.8490056887099904
#     Spin site 7 has not been flipped.
# Spin site 7 has been removed from active list
# Spin site 28:
#     Energy before flip is -1.410298410415209
#     Energy after flip is 1.410298410415209
#     Spin site 28 has not been flipped.
# Spin site 28 has been removed from active list
# Spin site 60:
#     Energy before flip is 0.39934127471688824
#     Energy after flip is -0.39934127471688824
#     Spin site 60 has been flipped.
# Spin site 32:
#     Energy before flip is -1.639736818348554
#     Energy after flip is 1.639736818348554
#     Spin site 32 has not been flipped.
# Spin site 32 has been removed from active list
# Spin site 59:
#     Energy before flip is -2.0573188168581327
#     Energy after flip is 2.0573188168581327
#     Spin site 59 has not been flipped.
# Spin site 59 has been removed from active list
# Spin site 69:
#     Energy before flip is -0.48040720525115627
#     Energy after flip is 0.48040720525115627
#     Spin site 69 has not been flipped.
# Spin site 69 has been removed from active list
# Spin site 96:
#     Energy before flip is -1.5244520574766587
#     Energy after flip is 1.5244520574766587
#     Spin site 96 has not been flipped.
# Spin site 96 has been removed from active list
# Spin site 70:
#     Energy before flip is -1.3501346591359074
#     Energy after flip is 1.3501346591359074
#     Spin site 70 has not been flipped.
# Spin site 70 has been removed from active list
# Spin site 82:
#     Energy before flip is -1.6352768780463538
#     Energy after flip is 1.6352768780463538
#     Spin site 82 has not been flipped.
# Spin site 82 has been removed from active list
# Spin site 92:
#     Energy before flip is -1.0373307136637258
#     Energy after flip is 1.0373307136637258
#     Spin site 92 has not been flipped.
# Spin site 92 has been removed from active list
# Spin site 33:
#     Energy before flip is 0.8296072916473295
#     Energy after flip is -0.8296072916473295
#     Spin site 33 has been flipped.
# Spin site 98:
#     Energy before flip is 0.7809090176820133
#     Energy after flip is -0.7809090176820133
#     Spin site 98 has been flipped.
# Spin site 99:
#     Energy before flip is -5.257346425165103
#     Energy after flip is 5.257346425165103
#     Spin site 99 has not been flipped.
# Spin site 99 has been removed from active list
# Spin site 10:
#     Energy before flip is 0.34984828558323294
#     Energy after flip is -0.34984828558323294
#     Spin site 10 has been flipped.
# Spin site 15:
#     Energy before flip is -0.9992483622837267
#     Energy after flip is 0.9992483622837267
#     Spin site 15 has not been flipped.
# Spin site 15 has been removed from active list
# Spin site 51:
#     Energy before flip is -2.13388870383472
#     Energy after flip is 2.13388870383472
#     Spin site 51 has not been flipped.
# Spin site 51 has been removed from active list
# Spin site 75:
#     Energy before flip is -0.7311821107336514
#     Energy after flip is 0.7311821107336514
#     Spin site 75 has not been flipped.
# Spin site 75 has been removed from active list
# Spin site 61:
#     Energy before flip is 1.887917580955869
#     Energy after flip is -1.887917580955869
#     Spin site 61 has been flipped.
# Spin site 50:
#     Energy before flip is -2.2022259314654837
#     Energy after flip is 2.2022259314654837
#     Spin site 50 has not been flipped.
# Spin site 50 has been removed from active list
# Spin site 77:
#     Energy before flip is -1.451295470952048
#     Energy after flip is 1.451295470952048
#     Spin site 77 has not been flipped.
# Spin site 77 has been removed from active list
# Spin site 81:
#     Energy before flip is -0.07712057709237663
#     Energy after flip is 0.07712057709237663
#     Spin site 81 has not been flipped.
# Spin site 81 has been removed from active list
# Spin site 53:
#     Energy before flip is -0.09274208850405835
#     Energy after flip is 0.09274208850405835
#     Spin site 53 has not been flipped.
# Spin site 53 has been removed from active list
# Spin site 22:
#     Energy before flip is -0.73594883846903
#     Energy after flip is 0.73594883846903
#     Spin site 22 has not been flipped.
# Spin site 22 has been removed from active list
# Spin site 97:
#     Energy before flip is 1.1281432731054548
#     Energy after flip is -1.1281432731054548
#     Spin site 97 has been flipped.
# Spin site 84:
#     Energy before flip is -1.0636352912687905
#     Energy after flip is 1.0636352912687905
#     Spin site 84 has not been flipped.
# Spin site 84 has been removed from active list
# Spin site 97:
#     Energy before flip is -1.1281432731054548
#     Energy after flip is 1.1281432731054548
#     Spin site 97 has not been flipped.
# Spin site 97 has been removed from active list
# Spin site 46:
#     Energy before flip is -1.458799777715225
#     Energy after flip is 1.458799777715225
#     Spin site 46 has not been flipped.
# Spin site 46 has been removed from active list
# Spin site 38:
#     Energy before flip is -0.921173479408916
#     Energy after flip is 0.921173479408916
#     Spin site 38 has not been flipped.
# Spin site 38 has been removed from active list
# Spin site 49:
#     Energy before flip is -2.0133144728720476
#     Energy after flip is 2.0133144728720476
#     Spin site 49 has not been flipped.
# Spin site 49 has been removed from active list
# Spin site 63:
#     Energy before flip is -0.4135115471713352
#     Energy after flip is 0.4135115471713352
#     Spin site 63 has not been flipped.
# Spin site 63 has been removed from active list
# Spin site 41:
#     Energy before flip is -0.775700420483278
#     Energy after flip is 0.775700420483278
#     Spin site 41 has not been flipped.
# Spin site 41 has been removed from active list
# Spin site 45:
#     Energy before flip is -0.7988416485076266
#     Energy after flip is 0.7988416485076266
#     Spin site 45 has not been flipped.
# Spin site 45 has been removed from active list
# Spin site 78:
#     Energy before flip is -1.0661388875678197
#     Energy after flip is 1.0661388875678197
#     Spin site 78 has not been flipped.
# Spin site 78 has been removed from active list
# Spin site 61:
#     Energy before flip is -1.887917580955869
#     Energy after flip is 1.887917580955869
#     Spin site 61 has not been flipped.
# Spin site 61 has been removed from active list
# Spin site 33:
#     Energy before flip is -0.8296072916473295
#     Energy after flip is 0.8296072916473295
#     Spin site 33 has not been flipped.
# Spin site 33 has been removed from active list
# Spin site 10:
#     Energy before flip is -0.34984828558323294
#     Energy after flip is 0.34984828558323294
#     Spin site 10 has not been flipped.
# Spin site 10 has been removed from active list
# Spin site 32:
#     Energy before flip is -3.5814077230875996
#     Energy after flip is 3.5814077230875996
#     Spin site 32 has not been flipped.
# Spin site 32 has been removed from active list
# Spin site 25:
#     Energy before flip is -1.9744334687298317
#     Energy after flip is 1.9744334687298317
#     Spin site 25 has not been flipped.
# Spin site 25 has been removed from active list
# Spin site 27:
#     Energy before flip is -0.3559656628570705
#     Energy after flip is 0.3559656628570705
#     Spin site 27 has not been flipped.
# Spin site 27 has been removed from active list
# Spin site 93:
#     Energy before flip is -0.6614464683234705
#     Energy after flip is 0.6614464683234705
#     Spin site 93 has not been flipped.
# Spin site 93 has been removed from active list
# Spin site 6:
#     Energy before flip is 0.011009842448486462
#     Energy after flip is -0.011009842448486462
#     Spin site 6 has been flipped.
# Spin site 34:
#     Energy before flip is 0.06439241142861027
#     Energy after flip is -0.06439241142861027
#     Spin site 34 has been flipped.
# Spin site 65:
#     Energy before flip is -1.519686861674046
#     Energy after flip is 1.519686861674046
#     Spin site 65 has not been flipped.
# Spin site 65 has been removed from active list
# Spin site 66:
#     Energy before flip is -1.781025159006983
#     Energy after flip is 1.781025159006983
#     Spin site 66 has not been flipped.
# Spin site 66 has been removed from active list
# Spin site 33:
#     Energy before flip is -1.112063613091716
#     Energy after flip is 1.112063613091716
#     Spin site 33 has not been flipped.
# Spin site 33 has been removed from active list
# Spin site 1:
#     Energy before flip is -2.6444356903997353
#     Energy after flip is 2.6444356903997353
#     Spin site 1 has not been flipped.
# Spin site 1 has been removed from active list
# Spin site 89:
#     Energy before flip is -3.1310490411225156
#     Energy after flip is 3.1310490411225156
#     Spin site 89 has not been flipped.
# Spin site 89 has been removed from active list
# Spin site 17:
#     Energy before flip is -0.49040727950381097
#     Energy after flip is 0.49040727950381097
#     Spin site 17 has not been flipped.
# Spin site 17 has been removed from active list
# Spin site 96:
#     Energy before flip is -0.5701364358378891
#     Energy after flip is 0.5701364358378891
#     Spin site 96 has not been flipped.
# Spin site 96 has been removed from active list
# Spin site 5:
#     Energy before flip is -0.8539113097111009
#     Energy after flip is 0.8539113097111009
#     Spin site 5 has not been flipped.
# Spin site 5 has been removed from active list
# Spin site 31:
#     Energy before flip is -2.9098965967774557
#     Energy after flip is 2.9098965967774557
#     Spin site 31 has not been flipped.
# Spin site 31 has been removed from active list
# Spin site 68:
#     Energy before flip is -1.0893947761149834
#     Energy after flip is 1.0893947761149834
#     Spin site 68 has not been flipped.
# Spin site 68 has been removed from active list
# Spin site 73:
#     Energy before flip is -2.315079371590645
#     Energy after flip is 2.315079371590645
#     Spin site 73 has not been flipped.
# Spin site 73 has been removed from active list
# Spin site 36:
#     Energy before flip is -0.5397200662365547
#     Energy after flip is 0.5397200662365547
#     Spin site 36 has not been flipped.
# Spin site 36 has been removed from active list
# Spin site 60:
#     Energy before flip is -1.353280973286302
#     Energy after flip is 1.353280973286302
#     Spin site 60 has not been flipped.
# Spin site 60 has been removed from active list
# Spin site 11:
#     Energy before flip is -0.0852413312716716
#     Energy after flip is 0.0852413312716716
#     Spin site 11 has not been flipped.
# Spin site 11 has been removed from active list
# Spin site 67:
#     Energy before flip is -2.4969826979514513
#     Energy after flip is 2.4969826979514513
#     Spin site 67 has not been flipped.
# Spin site 67 has been removed from active list
# Spin site 44:
#     Energy before flip is -0.45957275240027945
#     Energy after flip is 0.45957275240027945
#     Spin site 44 has not been flipped.
# Spin site 44 has been removed from active list
# Spin site 3:
#     Energy before flip is -0.7521154420585706
#     Energy after flip is 0.7521154420585706
#     Spin site 3 has not been flipped.
# Spin site 3 has been removed from active list
# Spin site 37:
#     Energy before flip is -2.5925895435257447
#     Energy after flip is 2.5925895435257447
#     Spin site 37 has not been flipped.
# Spin site 37 has been removed from active list
# Spin site 7:
#     Energy before flip is -1.6523684658516626
#     Energy after flip is 1.6523684658516626
#     Spin site 7 has not been flipped.
# Spin site 7 has been removed from active list
# Spin site 21:
#     Energy before flip is 1.545889128284506
#     Energy after flip is -1.545889128284506
#     Spin site 21 has been flipped.
# Spin site 35:
#     Energy before flip is 0.642365161239954
#     Energy after flip is -0.642365161239954
#     Spin site 35 has been flipped.
# Spin site 62:
#     Energy before flip is -1.1625025176161645
#     Energy after flip is 1.1625025176161645
#     Spin site 62 has not been flipped.
# Spin site 62 has been removed from active list
# Spin site 26:
#     Energy before flip is -0.8129700467290837
#     Energy after flip is 0.8129700467290837
#     Spin site 26 has not been flipped.
# Spin site 26 has been removed from active list
# Spin site 95:
#     Energy before flip is -1.2789607153755287
#     Energy after flip is 1.2789607153755287
#     Spin site 95 has not been flipped.
# Spin site 95 has been removed from active list
# Spin site 35:
#     Energy before flip is -0.642365161239954
#     Energy after flip is 0.642365161239954
#     Spin site 35 has not been flipped.
# Spin site 35 has been removed from active list
# Spin site 22:
#     Energy before flip is -1.0211960274355845
#     Energy after flip is 1.0211960274355845
#     Spin site 22 has not been flipped.
# Spin site 22 has been removed from active list
# Spin site 36:
#     Energy before flip is -1.6707788901292966
#     Energy after flip is 1.6707788901292966
#     Spin site 36 has not been flipped.
# Spin site 36 has been removed from active list
# Spin site 13:
#     Energy before flip is -2.316466865859666
#     Energy after flip is 2.316466865859666
#     Spin site 13 has not been flipped.
# Spin site 13 has been removed from active list
# Spin site 34:
#     Energy before flip is -0.21806391001577644
#     Energy after flip is 0.21806391001577644
#     Spin site 34 has not been flipped.
# Spin site 34 has been removed from active list
# Spin site 98:
#     Energy before flip is -3.9915111855316923
#     Energy after flip is 3.9915111855316923
#     Spin site 98 has not been flipped.
# Spin site 98 has been removed from active list
# Spin site 21:
#     Energy before flip is -1.545889128284506
#     Energy after flip is 1.545889128284506
#     Spin site 21 has not been flipped.
# Spin site 21 has been removed from active list
# Spin site 39:
#     Energy before flip is -0.5649593446821285
#     Energy after flip is 0.5649593446821285
#     Spin site 39 has not been flipped.
# Spin site 39 has been removed from active list
# Spin site 52:
#     Energy before flip is -0.07920336205747663
#     Energy after flip is 0.07920336205747663
#     Spin site 52 has not been flipped.
# Spin site 52 has been removed from active list
# Spin site 8:
#     Energy before flip is -1.7104312528537853
#     Energy after flip is 1.7104312528537853
#     Spin site 8 has not been flipped.
# Spin site 8 has been removed from active list
# Spin site 30:
#     Energy before flip is -0.0447410261613565
#     Energy after flip is 0.0447410261613565
#     Spin site 30 has not been flipped.
# Spin site 30 has been removed from active list
# Spin site 9:
#     Energy before flip is -0.8384509709103465
#     Energy after flip is 0.8384509709103465
#     Spin site 9 has not been flipped.
# Spin site 9 has been removed from active list
# Spin site 6:
#     Energy before flip is -0.011009842448486462
#     Energy after flip is 0.011009842448486462
#     Spin site 6 has not been flipped.
# Spin site 6 has been removed from active list
# Spin site 94:
#     Energy before flip is -0.1627639628399985
#     Energy after flip is 0.1627639628399985
#     Spin site 94 has not been flipped.
# Spin site 94 has been removed from active list
# Spin site 20:
#     Energy before flip is -2.990275150123546
#     Energy after flip is 2.990275150123546
#     Spin site 20 has not been flipped.
# Spin site 20 has been removed from active list
# Twin 2 has reached absorbing state.

# %%
def q_infinity(N):
    overlap = 0
    for spin in spin_dict_1:
        overlap += spin_dict_1[spin]*spin_dict_2[spin]
    overlap = overlap/N
    return overlap

# %%
q = q_infinity(100)
print(q)
# Out:
# 0.42

# %%
q_list = []
q_list.append(q)
# q_list.append(0.49)

# %%
print(q_list)
# Out:
# [0.42]

# %%
print(np.mean(q_list))
# Out:
# 0.42
